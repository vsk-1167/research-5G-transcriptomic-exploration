# %% [markdown]
# # GO Term Analysis

# %%
import pandas as pd 
import pickle
import seaborn as sns
import altair as alt

# %% [markdown]
# # Load Data

# %% [markdown]
# ## TPM Data for each Loci

# %%
condition_to_loci_file = "../data/new_sample2condition.txt"

# load mapping from sample to condition
with open(condition_to_loci_file,'r') as f:
    loci_to_ferm_run = str(f.readline()[1:(len(f.readline())-1)]).split(',')

    loci_tracker = dict(loci.replace('"', "").strip().split(':') for loci in loci_to_ferm_run)
    
conditions = list(set(map(str.strip, loci_tracker.values())))
conditions
# Out:
# ['highCu',
#  'NO3_lowO2_slow_growth',
#  'NoLanthanum',
#  'lowO2_low_iron_fast_growth',
#  'MeOH',
#  'unknown',
#  'WithLanthanum',
#  'WT_control',
#  'crotonic_acid',
#  'medCu',
#  'highO2_slow_growth',
#  'uMax',
#  'lowO2_fast_growth',
#  'lowO2_slow_growth',
#  'lowCH4',
#  'LanzaTech',
#  'aa3_KO',
#  'slow_growth',
#  'lowCu',
#  'NoCu']

# %%
loci_to_gene_symbol = "../data/loci2gene.p"
loci_to_gene = pickle.load(open(loci_to_gene_symbol, 'rb'))
loci_to_gene
# Out:
# {'EQU24_RS00005': 'dnaA',
#  'EQU24_RS00010': '',
#  'EQU24_RS00015': 'recF',
#  'EQU24_RS00020': 'gyrB',
#  'EQU24_RS00025': '',
#  'EQU24_RS00030': '',
#  'EQU24_RS00035': '',
#  'EQU24_RS00040': '',
#  'EQU24_RS00045': '',
#  'EQU24_RS00050': '',
#  'EQU24_RS00055': '',
#  'EQU24_RS00060': '',
#  'EQU24_RS00065': '',
#  'EQU24_RS00070': 'tatA',
#  'EQU24_RS00075': 'tatB',
#  'EQU24_RS00080': '',
#  'EQU24_RS00085': '',
#  'EQU24_RS00090': 'thyA',
#  'EQU24_RS00095': '',
#  'EQU24_RS00100': '',
#  'EQU24_RS00105': 'crp',
#  'EQU24_RS00110': '',
#  'EQU24_RS00115': 'speD',
#  'EQU24_RS00125': '',
#  'EQU24_RS00130': '',
#  'EQU24_RS00135': '',
#  'EQU24_RS00140': '',
#  'EQU24_RS00145': '',
#  'EQU24_RS00150': '',
#  'EQU24_RS00155': '',
#  'EQU24_RS00160': '',
#  'EQU24_RS00165': '',
#  'EQU24_RS00170': '',
#  'EQU24_RS00175': '',
#  'EQU24_RS00180': '',
#  'EQU24_RS00185': '',
#  'EQU24_RS00190': '',
#  'EQU24_RS00195': '',
#  'EQU24_RS00200': '',
#  'EQU24_RS00205': '',
#  'EQU24_RS00210': '',
#  'EQU24_RS00215': '',
#  'EQU24_RS00220': '',
#  'EQU24_RS00225': '',
#  'EQU24_RS00230': '',
#  'EQU24_RS00235': '',
#  'EQU24_RS00240': '',
#  'EQU24_RS00245': '',
#  'EQU24_RS00250': '',
#  'EQU24_RS00255': '',
#  'EQU24_RS00260': '',
#  'EQU24_RS00265': '',
#  'EQU24_RS00270': '',
#  'EQU24_RS00275': '',
#  'EQU24_RS00280': '',
#  'EQU24_RS00285': '',
#  'EQU24_RS00290': '',
#  'EQU24_RS00295': '',
#  'EQU24_RS00300': '',
#  'EQU24_RS00305': '',
#  'EQU24_RS00310': '',
#  'EQU24_RS00315': '',
#  'EQU24_RS00320': '',
#  'EQU24_RS00330': '',
#  'EQU24_RS00335': '',
#  'EQU24_RS00340': '',
#  'EQU24_RS00345': '',
#  'EQU24_RS00350': '',
#  'EQU24_RS00355': '',
#  'EQU24_RS00360': '',
#  'EQU24_RS00365': '',
#  'EQU24_RS00370': '',
#  'EQU24_RS00375': '',
#  'EQU24_RS00380': '',
#  'EQU24_RS00385': '',
#  'EQU24_RS00390': '',
#  'EQU24_RS00395': '',
#  'EQU24_RS00400': '',
#  'EQU24_RS00405': '',
#  'EQU24_RS00410': '',
#  'EQU24_RS00415': '',
#  'EQU24_RS00420': 'typA',
#  'EQU24_RS00425': 'hisB',
#  'EQU24_RS00430': 'hisH',
#  'EQU24_RS00435': 'hisA',
#  'EQU24_RS00440': 'hisF',
#  'EQU24_RS00445': 'hisI',
#  'EQU24_RS00450': '',
#  'EQU24_RS00455': 'tatA',
#  'EQU24_RS00460': 'tatB',
#  'EQU24_RS00465': 'tatC',
#  'EQU24_RS00470': '',
#  'EQU24_RS00475': '',
#  'EQU24_RS00480': '',
#  'EQU24_RS00485': 'folK',
#  'EQU24_RS00490': 'folB',
#  'EQU24_RS00495': 'plsY',
#  'EQU24_RS00500': 'tsaD',
#  'EQU24_RS00505': 'rpsU',
#  'EQU24_RS00510': '',
#  'EQU24_RS00515': '',
#  'EQU24_RS00520': 'rpoD',
#  'EQU24_RS00525': '',
#  'EQU24_RS00530': '',
#  'EQU24_RS00535': '',
#  'EQU24_RS00540': 'metF',
#  'EQU24_RS00545': '',
#  'EQU24_RS00550': '',
#  'EQU24_RS00555': '',
#  'EQU24_RS00560': '',
#  'EQU24_RS00565': '',
#  'EQU24_RS00570': 'guaB',
#  'EQU24_RS00575': 'guaA',
#  'EQU24_RS00580': 'tadA',
#  'EQU24_RS00585': '',
#  'EQU24_RS00590': '',
#  'EQU24_RS00595': '',
#  'EQU24_RS00600': '',
#  'EQU24_RS00605': '',
#  'EQU24_RS00610': '',
#  'EQU24_RS00615': '',
#  'EQU24_RS00620': 'msbA',
#  'EQU24_RS00625': '',
#  'EQU24_RS00630': '',
#  'EQU24_RS00635': '',
#  'EQU24_RS00640': '',
#  'EQU24_RS00645': '',
#  'EQU24_RS00650': '',
#  'EQU24_RS00655': '',
#  'EQU24_RS00660': '',
#  'EQU24_RS00665': '',
#  'EQU24_RS00670': '',
#  'EQU24_RS00675': '',
#  'EQU24_RS00680': '',
#  'EQU24_RS00685': '',
#  'EQU24_RS00690': '',
#  'EQU24_RS00695': '',
#  'EQU24_RS00700': '',
#  'EQU24_RS00705': '',
#  'EQU24_RS00710': '',
#  'EQU24_RS00715': 'djlA',
#  'EQU24_RS00720': '',
#  'EQU24_RS00725': '',
#  'EQU24_RS00730': 'coaBC',
#  'EQU24_RS00735': '',
#  'EQU24_RS00740': '',
#  'EQU24_RS00745': 'argB',
#  'EQU24_RS00750': '',
#  'EQU24_RS00760': '',
#  'EQU24_RS00765': '',
#  'EQU24_RS00770': '',
#  'EQU24_RS00775': '',
#  'EQU24_RS00780': '',
#  'EQU24_RS00785': '',
#  'EQU24_RS00790': '',
#  'EQU24_RS00795': '',
#  'EQU24_RS00800': '',
#  'EQU24_RS00805': '',
#  'EQU24_RS00810': '',
#  'EQU24_RS00815': '',
#  'EQU24_RS00820': '',
#  'EQU24_RS00825': '',
#  'EQU24_RS00830': 'trpC',
#  'EQU24_RS00835': 'trpD',
#  'EQU24_RS00840': '',
#  'EQU24_RS00845': '',
#  'EQU24_RS00850': '',
#  'EQU24_RS00855': '',
#  'EQU24_RS00860': '',
#  'EQU24_RS00865': 'hemW',
#  'EQU24_RS00870': 'pyrE',
#  'EQU24_RS00875': '',
#  'EQU24_RS00880': '',
#  'EQU24_RS00885': 'trmB',
#  'EQU24_RS00890': 'thiS',
#  'EQU24_RS00895': 'aroG',
#  'EQU24_RS00900': '',
#  'EQU24_RS00905': '',
#  'EQU24_RS00910': '',
#  'EQU24_RS00915': '',
#  'EQU24_RS00920': '',
#  'EQU24_RS00925': '',
#  'EQU24_RS00930': '',
#  'EQU24_RS00940': '',
#  'EQU24_RS00945': '',
#  'EQU24_RS00950': '',
#  'EQU24_RS00955': '',
#  'EQU24_RS00960': '',
#  'EQU24_RS00965': '',
#  'EQU24_RS00970': '',
#  'EQU24_RS00975': 'mepA',
#  'EQU24_RS00980': '',
#  'EQU24_RS00985': '',
#  'EQU24_RS00990': 'aqpZ',
#  'EQU24_RS00995': '',
#  'EQU24_RS01000': '',
#  'EQU24_RS01005': '',
#  'EQU24_RS01010': '',
#  'EQU24_RS01015': '',
#  'EQU24_RS01020': '',
#  'EQU24_RS01025': '',
#  'EQU24_RS01030': '',
#  'EQU24_RS01035': '',
#  'EQU24_RS01040': '',
#  'EQU24_RS01050': '',
#  'EQU24_RS01055': '',
#  'EQU24_RS01070': '',
#  'EQU24_RS01075': '',
#  'EQU24_RS01080': '',
#  'EQU24_RS01085': '',
#  'EQU24_RS01090': '',
#  'EQU24_RS01095': '',
#  'EQU24_RS01100': '',
#  'EQU24_RS01105': '',
#  'EQU24_RS01110': '',
#  'EQU24_RS01115': '',
#  'EQU24_RS01120': '',
#  'EQU24_RS01125': '',
#  'EQU24_RS01130': '',
#  'EQU24_RS01135': '',
#  'EQU24_RS01140': '',
#  'EQU24_RS01145': '',
#  'EQU24_RS01150': '',
#  'EQU24_RS01155': '',
#  'EQU24_RS01160': '',
#  'EQU24_RS01165': '',
#  'EQU24_RS01170': '',
#  'EQU24_RS01175': 'umuD',
#  'EQU24_RS01180': '',
#  'EQU24_RS01185': '',
#  'EQU24_RS01190': '',
#  'EQU24_RS01195': '',
#  'EQU24_RS01200': '',
#  'EQU24_RS01205': '',
#  'EQU24_RS01210': '',
#  'EQU24_RS01215': '',
#  'EQU24_RS01220': '',
#  'EQU24_RS01225': '',
#  'EQU24_RS01230': '',
#  'EQU24_RS01235': '',
#  'EQU24_RS01240': '',
#  'EQU24_RS01245': '',
#  'EQU24_RS01250': '',
#  'EQU24_RS01255': '',
#  'EQU24_RS01260': '',
#  'EQU24_RS01265': '',
#  'EQU24_RS01270': '',
#  'EQU24_RS01280': '',
#  'EQU24_RS01285': '',
#  'EQU24_RS01290': '',
#  'EQU24_RS01295': '',
#  'EQU24_RS01305': '',
#  'EQU24_RS01310': '',
#  'EQU24_RS01315': '',
#  'EQU24_RS01320': '',
#  'EQU24_RS01325': '',
#  'EQU24_RS01330': '',
#  'EQU24_RS01335': '',
#  'EQU24_RS01340': '',
#  'EQU24_RS01345': '',
#  'EQU24_RS01350': '',
#  'EQU24_RS01355': '',
#  'EQU24_RS01360': '',
#  'EQU24_RS01365': '',
#  'EQU24_RS01370': '',
#  'EQU24_RS01375': '',
#  'EQU24_RS01385': 'lexA',
#  'EQU24_RS01390': '',
#  'EQU24_RS01395': '',
#  'EQU24_RS01410': '',
#  'EQU24_RS01415': '',
#  'EQU24_RS01420': '',
#  'EQU24_RS01425': '',
#  'EQU24_RS01430': '',
#  'EQU24_RS01435': '',
#  'EQU24_RS01440': '',
#  'EQU24_RS01445': '',
#  'EQU24_RS01450': '',
#  'EQU24_RS01455': '',
#  'EQU24_RS01460': 'fdhD',
#  'EQU24_RS01465': '',
#  'EQU24_RS01470': '',
#  'EQU24_RS01475': '',
#  'EQU24_RS01480': '',
#  'EQU24_RS01485': '',
#  'EQU24_RS01490': '',
#  'EQU24_RS01495': '',
#  'EQU24_RS01500': '',
#  'EQU24_RS01505': '',
#  'EQU24_RS01510': '',
#  'EQU24_RS01515': '',
#  'EQU24_RS01520': '',
#  'EQU24_RS01525': '',
#  'EQU24_RS01530': '',
#  'EQU24_RS01535': '',
#  'EQU24_RS01540': '',
#  'EQU24_RS01545': '',
#  'EQU24_RS01550': 'pssA',
#  'EQU24_RS01555': '',
#  'EQU24_RS01560': '',
#  'EQU24_RS01565': '',
#  'EQU24_RS01570': '',
#  'EQU24_RS01575': '',
#  'EQU24_RS01580': '',
#  'EQU24_RS01585': '',
#  'EQU24_RS01590': '',
#  'EQU24_RS01595': '',
#  'EQU24_RS01600': '',
#  'EQU24_RS01605': '',
#  'EQU24_RS01610': '',
#  'EQU24_RS01615': '',
#  'EQU24_RS01620': '',
#  'EQU24_RS01625': '',
#  'EQU24_RS01630': '',
#  'EQU24_RS01635': '',
#  'EQU24_RS01640': '',
#  'EQU24_RS01645': '',
#  'EQU24_RS01650': 'cysW',
#  'EQU24_RS01655': 'cysT',
#  'EQU24_RS01660': '',
#  'EQU24_RS01665': '',
#  'EQU24_RS01670': '',
#  'EQU24_RS01675': '',
#  'EQU24_RS01680': '',
#  'EQU24_RS01685': '',
#  'EQU24_RS01690': '',
#  'EQU24_RS01695': '',
#  'EQU24_RS01700': '',
#  'EQU24_RS01705': '',
#  'EQU24_RS01710': 'fabG',
#  'EQU24_RS01715': '',
#  'EQU24_RS01720': '',
#  'EQU24_RS01725': '',
#  'EQU24_RS01730': '',
#  'EQU24_RS01735': '',
#  'EQU24_RS01740': '',
#  'EQU24_RS01745': '',
#  'EQU24_RS01750': '',
#  'EQU24_RS01755': '',
#  'EQU24_RS01760': 'cydX',
#  'EQU24_RS01765': '',
#  'EQU24_RS01770': '',
#  'EQU24_RS01775': '',
#  'EQU24_RS01780': '',
#  'EQU24_RS01785': '',
#  'EQU24_RS01790': '',
#  'EQU24_RS01795': '',
#  'EQU24_RS01800': '',
#  'EQU24_RS01810': '',
#  'EQU24_RS01815': '',
#  'EQU24_RS01820': '',
#  'EQU24_RS01825': '',
#  'EQU24_RS01830': 'hflB',
#  'EQU24_RS01835': 'mscL',
#  'EQU24_RS01840': '',
#  'EQU24_RS01845': '',
#  'EQU24_RS01855': '',
#  'EQU24_RS01860': '',
#  'EQU24_RS01870': '',
#  'EQU24_RS01880': '',
#  'EQU24_RS01885': '',
#  'EQU24_RS01890': '',
#  'EQU24_RS01895': '',
#  'EQU24_RS01900': '',
#  'EQU24_RS01905': '',
#  'EQU24_RS01910': '',
#  'EQU24_RS01915': '',
#  'EQU24_RS01920': '',
#  'EQU24_RS01925': '',
#  'EQU24_RS01930': '',
#  'EQU24_RS01935': '',
#  'EQU24_RS01940': '',
#  'EQU24_RS01945': '',
#  'EQU24_RS01950': '',
#  'EQU24_RS01955': '',
#  'EQU24_RS01960': '',
#  'EQU24_RS01965': '',
#  'EQU24_RS01970': '',
#  'EQU24_RS01975': '',
#  'EQU24_RS01980': '',
#  'EQU24_RS01985': '',
#  'EQU24_RS01990': '',
#  'EQU24_RS01995': '',
#  'EQU24_RS02000': '',
#  'EQU24_RS02005': '',
#  'EQU24_RS02010': '',
#  'EQU24_RS02015': '',
#  'EQU24_RS02020': '',
#  'EQU24_RS02025': '',
#  'EQU24_RS02030': '',
#  'EQU24_RS02035': 'rdgB',
#  'EQU24_RS02040': '',
#  'EQU24_RS02045': '',
#  'EQU24_RS02050': '',
#  'EQU24_RS02055': '',
#  'EQU24_RS02060': '',
#  'EQU24_RS02065': '',
#  'EQU24_RS02070': '',
#  'EQU24_RS02075': '',
#  'EQU24_RS02080': '',
#  'EQU24_RS02085': '',
#  'EQU24_RS02090': '',
#  'EQU24_RS02100': '',
#  'EQU24_RS02105': 'rep',
#  'EQU24_RS02110': '',
#  'EQU24_RS02115': '',
#  'EQU24_RS02120': '',
#  'EQU24_RS02125': '',
#  'EQU24_RS02130': '',
#  'EQU24_RS02135': '',
#  'EQU24_RS02140': '',
#  'EQU24_RS02150': '',
#  'EQU24_RS02155': '',
#  'EQU24_RS02160': '',
#  'EQU24_RS02165': '',
#  'EQU24_RS02170': '',
#  'EQU24_RS02175': '',
#  'EQU24_RS02180': '',
#  'EQU24_RS02185': '',
#  'EQU24_RS02190': '',
#  'EQU24_RS02195': '',
#  'EQU24_RS02200': '',
#  'EQU24_RS02205': 'mnmG',
#  'EQU24_RS02210': 'rsmG',
#  'EQU24_RS02215': '',
#  'EQU24_RS02220': '',
#  'EQU24_RS02225': '',
#  'EQU24_RS02230': 'atpB',
#  'EQU24_RS02235': 'atpE',
#  'EQU24_RS02240': '',
#  'EQU24_RS02245': '',
#  'EQU24_RS02250': '',
#  'EQU24_RS02255': 'atpG',
#  'EQU24_RS02260': 'atpD',
#  'EQU24_RS02265': '',
#  'EQU24_RS02270': 'glmU',
#  'EQU24_RS02275': 'glmS',
#  'EQU24_RS02285': '',
#  'EQU24_RS02290': '',
#  'EQU24_RS02295': '',
#  'EQU24_RS02300': '',
#  'EQU24_RS02305': '',
#  'EQU24_RS02310': '',
#  'EQU24_RS02315': '',
#  'EQU24_RS02320': '',
#  'EQU24_RS02325': '',
#  'EQU24_RS02330': '',
#  'EQU24_RS02335': 'smrA',
#  'EQU24_RS02340': '',
#  'EQU24_RS02345': '',
#  'EQU24_RS02350': '',
#  'EQU24_RS02355': '',
#  'EQU24_RS02360': '',
#  'EQU24_RS02365': '',
#  'EQU24_RS02370': '',
#  'EQU24_RS02375': '',
#  'EQU24_RS02380': '',
#  'EQU24_RS02385': '',
#  'EQU24_RS02390': '',
#  'EQU24_RS02395': '',
#  'EQU24_RS02400': '',
#  'EQU24_RS02405': '',
#  'EQU24_RS02410': '',
#  'EQU24_RS02415': '',
#  'EQU24_RS02420': '',
#  'EQU24_RS02425': '',
#  'EQU24_RS02430': '',
#  'EQU24_RS02435': '',
#  'EQU24_RS02440': 'polA',
#  'EQU24_RS02445': '',
#  'EQU24_RS02450': '',
#  'EQU24_RS02455': '',
#  'EQU24_RS02460': '',
#  'EQU24_RS02465': '',
#  'EQU24_RS02470': '',
#  'EQU24_RS02475': '',
#  'EQU24_RS02485': '',
#  'EQU24_RS02490': 'thpR',
#  'EQU24_RS02495': '',
#  'EQU24_RS02500': '',
#  'EQU24_RS02505': '',
#  'EQU24_RS02510': '',
#  'EQU24_RS02515': 'tusE',
#  'EQU24_RS02520': '',
#  'EQU24_RS02525': '',
#  'EQU24_RS02530': '',
#  'EQU24_RS02535': '',
#  'EQU24_RS02540': 'ispH',
#  'EQU24_RS02545': '',
#  'EQU24_RS02550': '',
#  'EQU24_RS02555': '',
#  'EQU24_RS02560': '',
#  'EQU24_RS02565': '',
#  'EQU24_RS02570': '',
#  'EQU24_RS02575': '',
#  'EQU24_RS02580': '',
#  'EQU24_RS02585': '',
#  'EQU24_RS02590': 'nth',
#  'EQU24_RS02595': '',
#  'EQU24_RS02600': 'rsxG',
#  'EQU24_RS02605': 'rsxD',
#  'EQU24_RS02610': 'rsxC',
#  'EQU24_RS02615': 'rsxB',
#  'EQU24_RS02620': 'rsxA',
#  'EQU24_RS02625': '',
#  'EQU24_RS02630': 'gmd',
#  'EQU24_RS02635': '',
#  'EQU24_RS02640': 'secA',
#  'EQU24_RS02645': '',
#  'EQU24_RS02650': 'trmL',
#  'EQU24_RS02655': '',
#  'EQU24_RS02660': 'secB',
#  'EQU24_RS02665': '',
#  'EQU24_RS02670': '',
#  'EQU24_RS02675': '',
#  'EQU24_RS02680': '',
#  'EQU24_RS02685': '',
#  'EQU24_RS02690': '',
#  'EQU24_RS02695': '',
#  'EQU24_RS02700': '',
#  'EQU24_RS02705': '',
#  'EQU24_RS02710': '',
#  'EQU24_RS02715': 'erpA',
#  'EQU24_RS02720': '',
#  'EQU24_RS02725': '',
#  'EQU24_RS02730': '',
#  'EQU24_RS02735': '',
#  'EQU24_RS02740': '',
#  'EQU24_RS02745': '',
#  'EQU24_RS02750': '',
#  'EQU24_RS02755': '',
#  'EQU24_RS02760': '',
#  'EQU24_RS02765': '',
#  'EQU24_RS02770': '',
#  'EQU24_RS02775': '',
#  'EQU24_RS02780': '',
#  'EQU24_RS02785': '',
#  'EQU24_RS02790': '',
#  'EQU24_RS02795': '',
#  'EQU24_RS02800': 'pyrF',
#  'EQU24_RS02805': '',
#  'EQU24_RS02810': '',
#  'EQU24_RS02815': '',
#  'EQU24_RS02820': 'pdxJ',
#  'EQU24_RS02825': 'recO',
#  'EQU24_RS02830': '',
#  'EQU24_RS02835': '',
#  'EQU24_RS02840': '',
#  'EQU24_RS02845': 'lepB',
#  'EQU24_RS02850': 'lepA',
#  'EQU24_RS02855': '',
#  'EQU24_RS02860': '',
#  'EQU24_RS02865': '',
#  'EQU24_RS02870': 'rpoE',
#  'EQU24_RS02875': 'nadB',
#  'EQU24_RS02880': '',
#  'EQU24_RS02885': '',
#  'EQU24_RS02890': '',
#  'EQU24_RS02895': '',
#  'EQU24_RS02900': '',
#  'EQU24_RS02905': 'dmeF',
#  'EQU24_RS02915': '',
#  'EQU24_RS02920': '',
#  'EQU24_RS02930': '',
#  'EQU24_RS02935': 'pip',
#  'EQU24_RS02940': '',
#  'EQU24_RS02945': 'pqqE',
#  'EQU24_RS02950': 'pqqD',
#  'EQU24_RS02955': '',
#  'EQU24_RS02960': 'pqqC',
#  'EQU24_RS02965': 'pqqB',
#  'EQU24_RS02970': 'pqqA',
#  'EQU24_RS02975': '',
#  'EQU24_RS02980': '',
#  'EQU24_RS02985': '',
#  'EQU24_RS02990': '',
#  'EQU24_RS02995': '',
#  'EQU24_RS03000': '',
#  'EQU24_RS03005': '',
#  'EQU24_RS03010': '',
#  'EQU24_RS03015': '',
#  'EQU24_RS03020': '',
#  'EQU24_RS03025': 'hcp',
#  'EQU24_RS03030': '',
#  'EQU24_RS03035': 'yidD',
#  'EQU24_RS03040': '',
#  'EQU24_RS03045': '',
#  'EQU24_RS03050': '',
#  'EQU24_RS03055': '',
#  'EQU24_RS03060': '',
#  'EQU24_RS03070': '',
#  'EQU24_RS03075': 'fetB',
#  'EQU24_RS03080': '',
#  'EQU24_RS03085': '',
#  'EQU24_RS03090': '',
#  'EQU24_RS03095': '',
#  'EQU24_RS03100': '',
#  'EQU24_RS03105': '',
#  'EQU24_RS03110': '',
#  'EQU24_RS03115': 'petA',
#  'EQU24_RS03120': '',
#  'EQU24_RS03125': 'hisD',
#  'EQU24_RS03130': '',
#  'EQU24_RS03135': 'murA',
#  'EQU24_RS03140': '',
#  'EQU24_RS03145': 'mlaD',
#  'EQU24_RS03150': 'mlaE',
#  'EQU24_RS03155': '',
#  'EQU24_RS03160': '',
#  'EQU24_RS03165': '',
#  'EQU24_RS03170': 'kdsC',
#  'EQU24_RS03175': 'lptC',
#  'EQU24_RS03180': 'lptA',
#  'EQU24_RS03185': 'lptB',
#  'EQU24_RS03190': '',
#  'EQU24_RS03195': 'raiA',
#  'EQU24_RS03200': 'rapZ',
#  'EQU24_RS03205': '',
#  'EQU24_RS03210': 'minE',
#  'EQU24_RS03215': 'minD',
#  'EQU24_RS03220': 'minC',
#  'EQU24_RS03225': '',
#  'EQU24_RS03230': 'thiC',
#  'EQU24_RS03235': '',
#  'EQU24_RS03250': '',
#  'EQU24_RS03255': '',
#  'EQU24_RS03260': '',
#  'EQU24_RS03265': '',
#  'EQU24_RS03270': '',
#  'EQU24_RS03275': '',
#  'EQU24_RS03280': '',
#  'EQU24_RS03290': '',
#  'EQU24_RS03295': 'panB',
#  'EQU24_RS03300': 'folK',
#  'EQU24_RS03305': 'pcnB',
#  'EQU24_RS03310': '',
#  'EQU24_RS03315': '',
#  'EQU24_RS03320': 'lptG',
#  'EQU24_RS03325': 'lptF',
#  'EQU24_RS03330': '',
#  'EQU24_RS03335': '',
#  'EQU24_RS03340': '',
#  'EQU24_RS03345': 'pilB',
#  'EQU24_RS03350': '',
#  'EQU24_RS03355': '',
#  'EQU24_RS03360': '',
#  'EQU24_RS03365': 'zapD',
#  'EQU24_RS03370': 'yacG',
#  'EQU24_RS03375': '',
#  'EQU24_RS03380': '',
#  'EQU24_RS03385': 'grpE',
#  'EQU24_RS03390': '',
#  'EQU24_RS03395': '',
#  'EQU24_RS03400': '',
#  'EQU24_RS03405': '',
#  'EQU24_RS03415': '',
#  'EQU24_RS03420': '',
#  'EQU24_RS03425': '',
#  'EQU24_RS03435': '',
#  'EQU24_RS03440': '',
#  'EQU24_RS03445': '',
#  'EQU24_RS03450': '',
#  'EQU24_RS03455': '',
#  'EQU24_RS03460': '',
#  'EQU24_RS03465': '',
#  'EQU24_RS03470': '',
#  'EQU24_RS03475': '',
#  'EQU24_RS03480': 'glk',
#  'EQU24_RS03485': '',
#  'EQU24_RS03490': '',
#  'EQU24_RS03495': '',
#  'EQU24_RS03500': '',
#  'EQU24_RS03505': 'glyQ',
#  'EQU24_RS03510': '',
#  'EQU24_RS03515': '',
#  'EQU24_RS03520': '',
#  'EQU24_RS03525': 'lnt',
#  'EQU24_RS03535': '',
#  'EQU24_RS03540': '',
#  'EQU24_RS03545': '',
#  'EQU24_RS03550': 'ltrA',
#  'EQU24_RS03555': '',
#  'EQU24_RS03560': '',
#  'EQU24_RS03565': '',
#  'EQU24_RS03570': '',
#  'EQU24_RS03575': '',
#  'EQU24_RS03580': '',
#  'EQU24_RS03585': '',
#  'EQU24_RS03590': '',
#  'EQU24_RS03595': '',
#  'EQU24_RS03600': '',
#  'EQU24_RS03605': '',
#  'EQU24_RS03610': 'ectA',
#  'EQU24_RS03615': 'ectB',
#  'EQU24_RS03620': '',
#  'EQU24_RS03625': '',
#  'EQU24_RS03630': '',
#  'EQU24_RS03635': '',
#  'EQU24_RS03640': '',
#  'EQU24_RS03645': '',
#  'EQU24_RS03650': '',
#  'EQU24_RS03655': 'lipA',
#  'EQU24_RS03660': 'lipB',
#  'EQU24_RS03665': '',
#  'EQU24_RS03670': '',
#  'EQU24_RS03675': '',
#  'EQU24_RS03680': 'mltB',
#  'EQU24_RS03685': 'rodA',
#  'EQU24_RS03690': 'mrdA',
#  'EQU24_RS03695': 'mreD',
#  'EQU24_RS03700': 'mreC',
#  'EQU24_RS03705': '',
#  'EQU24_RS03710': 'gatC',
#  'EQU24_RS03715': 'gatA',
#  'EQU24_RS03720': '',
#  'EQU24_RS03725': 'gatB',
#  'EQU24_RS03730': '',
#  'EQU24_RS03735': '',
#  'EQU24_RS03740': 'prmC',
#  'EQU24_RS03745': 'prfA',
#  'EQU24_RS03750': '',
#  'EQU24_RS03755': '',
#  'EQU24_RS03760': 'lolB',
#  'EQU24_RS03765': 'ispE',
#  'EQU24_RS03770': '',
#  'EQU24_RS03775': '',
#  'EQU24_RS03780': '',
#  'EQU24_RS03785': '',
#  'EQU24_RS03790': '',
#  'EQU24_RS03795': '',
#  'EQU24_RS03800': 'tuf',
#  'EQU24_RS03805': '',
#  'EQU24_RS03810': 'secE',
#  'EQU24_RS03815': 'nusG',
#  'EQU24_RS03820': 'rplK',
#  'EQU24_RS03825': 'rplA',
#  'EQU24_RS03830': '',
#  'EQU24_RS03835': 'rplL',
#  'EQU24_RS03840': 'rpoB',
#  'EQU24_RS03845': 'rpoC',
#  'EQU24_RS03850': 'rpsL',
#  'EQU24_RS03855': 'rpsG',
#  'EQU24_RS03860': 'fusA',
#  'EQU24_RS03865': 'tuf',
#  'EQU24_RS03870': 'rpsJ',
#  'EQU24_RS03875': 'rplC',
#  'EQU24_RS03880': 'rplD',
#  'EQU24_RS03885': '',
#  'EQU24_RS03890': 'rplB',
#  'EQU24_RS03895': 'rpsS',
#  'EQU24_RS03900': '',
#  'EQU24_RS03905': 'rpsC',
#  'EQU24_RS03910': 'rplP',
#  'EQU24_RS03915': 'rpmC',
#  'EQU24_RS03920': 'rpsQ',
#  'EQU24_RS03925': 'rplN',
#  'EQU24_RS03930': 'rplX',
#  'EQU24_RS03935': 'rplE',
#  'EQU24_RS03940': 'rpsN',
#  'EQU24_RS03945': 'rpsH',
#  'EQU24_RS03950': 'rplF',
#  'EQU24_RS03955': '',
#  'EQU24_RS03960': '',
#  'EQU24_RS03965': 'rpmD',
#  'EQU24_RS03970': 'rplO',
#  'EQU24_RS03975': 'secY',
#  'EQU24_RS03980': 'rpmJ',
#  'EQU24_RS03985': 'rpsM',
#  'EQU24_RS03990': 'rpsK',
#  'EQU24_RS03995': 'rpsD',
#  'EQU24_RS04000': 'rpoA',
#  'EQU24_RS04005': '',
#  'EQU24_RS04010': '',
#  'EQU24_RS04015': '',
#  'EQU24_RS04020': '',
#  'EQU24_RS04025': 'sodB',
#  'EQU24_RS04030': '',
#  'EQU24_RS04035': 'moaC',
#  'EQU24_RS04040': 'moaD',
#  'EQU24_RS04045': '',
#  'EQU24_RS04050': '',
#  'EQU24_RS04055': '',
#  'EQU24_RS04060': '',
#  'EQU24_RS04065': 'ilvN',
#  'EQU24_RS04070': 'ilvC',
#  'EQU24_RS04075': 'pssA',
#  'EQU24_RS04080': '',
#  'EQU24_RS04085': '',
#  'EQU24_RS04090': 'rimI',
#  'EQU24_RS04095': '',
#  'EQU24_RS04100': '',
#  'EQU24_RS04110': '',
#  'EQU24_RS04115': '',
#  'EQU24_RS04120': '',
#  'EQU24_RS04125': '',
#  'EQU24_RS04130': 'ltrA',
#  'EQU24_RS04135': '',
#  'EQU24_RS04140': '',
#  'EQU24_RS04145': '',
#  'EQU24_RS04150': '',
#  'EQU24_RS04155': '',
#  'EQU24_RS04160': '',
#  'EQU24_RS04165': '',
#  'EQU24_RS04170': '',
#  'EQU24_RS04175': '',
#  'EQU24_RS04185': 'pepP',
#  'EQU24_RS04190': 'ubiH',
#  'EQU24_RS04195': '',
#  'EQU24_RS04200': '',
#  'EQU24_RS04205': '',
#  'EQU24_RS04210': '',
#  'EQU24_RS04215': 'sucC',
#  'EQU24_RS04220': 'sucD',
#  'EQU24_RS04225': '',
#  'EQU24_RS04230': '',
#  'EQU24_RS04235': '',
#  'EQU24_RS04240': '',
#  'EQU24_RS04245': '',
#  'EQU24_RS04250': '',
#  'EQU24_RS04255': 'rpmE',
#  'EQU24_RS04260': '',
#  'EQU24_RS04265': '',
#  'EQU24_RS04270': '',
#  'EQU24_RS04275': '',
#  'EQU24_RS04280': '',
#  'EQU24_RS04285': '',
#  'EQU24_RS04290': '',
#  'EQU24_RS04295': '',
#  'EQU24_RS04305': '',
#  'EQU24_RS04315': '',
#  'EQU24_RS04320': '',
#  'EQU24_RS04325': '',
#  'EQU24_RS04330': '',
#  'EQU24_RS04335': '',
#  'EQU24_RS04340': '',
#  'EQU24_RS04350': '',
#  'EQU24_RS04355': '',
#  'EQU24_RS04360': '',
#  'EQU24_RS04365': '',
#  'EQU24_RS04370': '',
#  'EQU24_RS04375': '',
#  'EQU24_RS04380': '',
#  'EQU24_RS04395': '',
#  'EQU24_RS04400': '',
#  'EQU24_RS04405': '',
#  'EQU24_RS04410': '',
#  'EQU24_RS04415': '',
#  'EQU24_RS04420': '',
#  'EQU24_RS04425': '',
#  'EQU24_RS04430': '',
#  'EQU24_RS04435': '',
#  'EQU24_RS04440': '',
#  'EQU24_RS04445': '',
#  'EQU24_RS04450': '',
#  'EQU24_RS04455': '',
#  'EQU24_RS04460': '',
#  'EQU24_RS04465': '',
#  'EQU24_RS04470': '',
#  'EQU24_RS04475': '',
#  'EQU24_RS04480': '',
#  'EQU24_RS04485': '',
#  'EQU24_RS04490': 'pilQ',
#  'EQU24_RS04500': 'aroK',
#  'EQU24_RS04505': 'aroB',
#  'EQU24_RS04510': '',
#  'EQU24_RS04515': 'hemE',
#  'EQU24_RS04520': '',
#  'EQU24_RS04525': '',
#  'EQU24_RS04530': '',
#  'EQU24_RS04535': '',
#  'EQU24_RS04545': 'cpsG',
#  'EQU24_RS04550': '',
#  'EQU24_RS04555': '',
#  'EQU24_RS04560': '',
#  'EQU24_RS04565': '',
#  'EQU24_RS04570': '',
#  'EQU24_RS04575': '',
#  'EQU24_RS04580': '',
#  'EQU24_RS04585': '',
#  'EQU24_RS04590': '',
#  'EQU24_RS04595': '',
#  'EQU24_RS04600': '',
#  'EQU24_RS04605': '',
#  'EQU24_RS04610': 'pilV',
#  'EQU24_RS04615': '',
#  'EQU24_RS04625': '',
#  'EQU24_RS04630': '',
#  'EQU24_RS04635': '',
#  'EQU24_RS04640': 'sucD',
#  'EQU24_RS04645': '',
#  'EQU24_RS04650': '',
#  'EQU24_RS04655': '',
#  'EQU24_RS04660': '',
#  'EQU24_RS04665': '',
#  'EQU24_RS04670': '',
#  'EQU24_RS04675': '',
#  'EQU24_RS04680': '',
#  'EQU24_RS04685': '',
#  'EQU24_RS04690': '',
#  'EQU24_RS04695': '',
#  'EQU24_RS04700': '',
#  'EQU24_RS04705': 'rsmA',
#  'EQU24_RS04710': 'pdxA',
#  'EQU24_RS04715': '',
#  'EQU24_RS04720': '',
#  'EQU24_RS04725': '',
#  'EQU24_RS04730': '',
#  'EQU24_RS04735': '',
#  'EQU24_RS04740': '',
#  'EQU24_RS04745': '',
#  'EQU24_RS04750': '',
#  'EQU24_RS04755': '',
#  'EQU24_RS04760': '',
#  'EQU24_RS04765': '',
#  'EQU24_RS04770': '',
#  'EQU24_RS04775': '',
#  'EQU24_RS04780': '',
#  'EQU24_RS04785': '',
#  'EQU24_RS04790': '',
#  'EQU24_RS04795': '',
#  'EQU24_RS04800': '',
#  'EQU24_RS04805': 'prs',
#  'EQU24_RS04810': '',
#  'EQU24_RS04815': '',
#  'EQU24_RS04820': 'bamA',
#  'EQU24_RS04825': '',
#  'EQU24_RS04830': 'fabZ',
#  'EQU24_RS04835': 'lpxA',
#  'EQU24_RS04840': 'rnhB',
#  'EQU24_RS04845': 'dnaE',
#  'EQU24_RS04850': '',
#  'EQU24_RS04855': 'rluC',
#  'EQU24_RS04860': '',
#  'EQU24_RS04865': 'sppA',
#  'EQU24_RS04870': '',
#  'EQU24_RS04875': '',
#  'EQU24_RS04880': 'radA',
#  'EQU24_RS04885': '',
#  'EQU24_RS04890': '',
#  'EQU24_RS04895': '',
#  'EQU24_RS04900': '',
#  'EQU24_RS04905': '',
#  'EQU24_RS04910': '',
#  'EQU24_RS04915': 'fliE',
#  'EQU24_RS04920': 'fliF',
#  'EQU24_RS04925': 'fliG',
#  'EQU24_RS04930': '',
#  'EQU24_RS04935': 'fliI',
#  'EQU24_RS04940': 'fliJ',
#  'EQU24_RS04945': '',
#  'EQU24_RS04950': '',
#  'EQU24_RS04955': '',
#  'EQU24_RS04960': '',
#  'EQU24_RS04965': '',
#  'EQU24_RS04970': 'msrP',
#  'EQU24_RS04975': '',
#  'EQU24_RS04980': '',
#  'EQU24_RS04985': '',
#  'EQU24_RS04990': '',
#  'EQU24_RS04995': '',
#  'EQU24_RS05000': '',
#  'EQU24_RS05005': '',
#  'EQU24_RS05010': '',
#  'EQU24_RS05015': '',
#  'EQU24_RS05020': '',
#  'EQU24_RS05025': '',
#  'EQU24_RS05030': '',
#  'EQU24_RS05035': '',
#  'EQU24_RS05040': '',
#  'EQU24_RS05045': '',
#  'EQU24_RS05050': '',
#  'EQU24_RS05055': '',
#  'EQU24_RS05060': '',
#  'EQU24_RS05065': '',
#  'EQU24_RS05070': '',
#  'EQU24_RS05075': '',
#  'EQU24_RS05080': '',
#  'EQU24_RS05085': '',
#  'EQU24_RS05090': '',
#  'EQU24_RS05095': '',
#  'EQU24_RS05100': '',
#  'EQU24_RS05105': 'gspE',
#  'EQU24_RS05110': '',
#  'EQU24_RS05115': 'gspG',
#  'EQU24_RS05120': 'gspH',
#  'EQU24_RS05125': '',
#  'EQU24_RS05130': '',
#  'EQU24_RS05135': '',
#  'EQU24_RS05140': '',
#  'EQU24_RS05145': '',
#  'EQU24_RS05150': '',
#  'EQU24_RS05155': '',
#  'EQU24_RS05160': 'gspD',
#  'EQU24_RS05165': '',
#  'EQU24_RS05170': 'nrdR',
#  'EQU24_RS05175': 'ribD',
#  'EQU24_RS05180': '',
#  'EQU24_RS05185': '',
#  'EQU24_RS05190': 'ribE',
#  'EQU24_RS05195': 'nusB',
#  ...}

# %%
loci_to_product_file = "../data/loci2product.p"
loci_to_product = pickle.load(open(loci_to_product_file, 'rb'))
loci_to_product
# Out:
# {'EQU24_RS00005': 'dnaA',
#  'EQU24_RS00010': '',
#  'EQU24_RS00015': 'recF',
#  'EQU24_RS00020': 'gyrB',
#  'EQU24_RS00025': '',
#  'EQU24_RS00030': '',
#  'EQU24_RS00035': '',
#  'EQU24_RS00040': '',
#  'EQU24_RS00045': '',
#  'EQU24_RS00050': '',
#  'EQU24_RS00055': '',
#  'EQU24_RS00060': '',
#  'EQU24_RS00065': '',
#  'EQU24_RS00070': 'tatA',
#  'EQU24_RS00075': 'tatB',
#  'EQU24_RS00080': '',
#  'EQU24_RS00085': '',
#  'EQU24_RS00090': 'thyA',
#  'EQU24_RS00095': '',
#  'EQU24_RS00100': '',
#  'EQU24_RS00105': 'crp',
#  'EQU24_RS00110': '',
#  'EQU24_RS00115': 'speD',
#  'EQU24_RS00125': '',
#  'EQU24_RS00130': '',
#  'EQU24_RS00135': '',
#  'EQU24_RS00140': '',
#  'EQU24_RS00145': '',
#  'EQU24_RS00150': '',
#  'EQU24_RS00155': '',
#  'EQU24_RS00160': '',
#  'EQU24_RS00165': '',
#  'EQU24_RS00170': '',
#  'EQU24_RS00175': '',
#  'EQU24_RS00180': '',
#  'EQU24_RS00185': '',
#  'EQU24_RS00190': '',
#  'EQU24_RS00195': '',
#  'EQU24_RS00200': '',
#  'EQU24_RS00205': '',
#  'EQU24_RS00210': '',
#  'EQU24_RS00215': '',
#  'EQU24_RS00220': '',
#  'EQU24_RS00225': '',
#  'EQU24_RS00230': '',
#  'EQU24_RS00235': '',
#  'EQU24_RS00240': '',
#  'EQU24_RS00245': '',
#  'EQU24_RS00250': '',
#  'EQU24_RS00255': '',
#  'EQU24_RS00260': '',
#  'EQU24_RS00265': '',
#  'EQU24_RS00270': '',
#  'EQU24_RS00275': '',
#  'EQU24_RS00280': '',
#  'EQU24_RS00285': '',
#  'EQU24_RS00290': '',
#  'EQU24_RS00295': '',
#  'EQU24_RS00300': '',
#  'EQU24_RS00305': '',
#  'EQU24_RS00310': '',
#  'EQU24_RS00315': '',
#  'EQU24_RS00320': '',
#  'EQU24_RS00330': '',
#  'EQU24_RS00335': '',
#  'EQU24_RS00340': '',
#  'EQU24_RS00345': '',
#  'EQU24_RS00350': '',
#  'EQU24_RS00355': '',
#  'EQU24_RS00360': '',
#  'EQU24_RS00365': '',
#  'EQU24_RS00370': '',
#  'EQU24_RS00375': '',
#  'EQU24_RS00380': '',
#  'EQU24_RS00385': '',
#  'EQU24_RS00390': '',
#  'EQU24_RS00395': '',
#  'EQU24_RS00400': '',
#  'EQU24_RS00405': '',
#  'EQU24_RS00410': '',
#  'EQU24_RS00415': '',
#  'EQU24_RS00420': 'typA',
#  'EQU24_RS00425': 'hisB',
#  'EQU24_RS00430': 'hisH',
#  'EQU24_RS00435': 'hisA',
#  'EQU24_RS00440': 'hisF',
#  'EQU24_RS00445': 'hisI',
#  'EQU24_RS00450': '',
#  'EQU24_RS00455': 'tatA',
#  'EQU24_RS00460': 'tatB',
#  'EQU24_RS00465': 'tatC',
#  'EQU24_RS00470': '',
#  'EQU24_RS00475': '',
#  'EQU24_RS00480': '',
#  'EQU24_RS00485': 'folK',
#  'EQU24_RS00490': 'folB',
#  'EQU24_RS00495': 'plsY',
#  'EQU24_RS00500': 'tsaD',
#  'EQU24_RS00505': 'rpsU',
#  'EQU24_RS00510': '',
#  'EQU24_RS00515': '',
#  'EQU24_RS00520': 'rpoD',
#  'EQU24_RS00525': '',
#  'EQU24_RS00530': '',
#  'EQU24_RS00535': '',
#  'EQU24_RS00540': 'metF',
#  'EQU24_RS00545': '',
#  'EQU24_RS00550': '',
#  'EQU24_RS00555': '',
#  'EQU24_RS00560': '',
#  'EQU24_RS00565': '',
#  'EQU24_RS00570': 'guaB',
#  'EQU24_RS00575': 'guaA',
#  'EQU24_RS00580': 'tadA',
#  'EQU24_RS00585': '',
#  'EQU24_RS00590': '',
#  'EQU24_RS00595': '',
#  'EQU24_RS00600': '',
#  'EQU24_RS00605': '',
#  'EQU24_RS00610': '',
#  'EQU24_RS00615': '',
#  'EQU24_RS00620': 'msbA',
#  'EQU24_RS00625': '',
#  'EQU24_RS00630': '',
#  'EQU24_RS00635': '',
#  'EQU24_RS00640': '',
#  'EQU24_RS00645': '',
#  'EQU24_RS00650': '',
#  'EQU24_RS00655': '',
#  'EQU24_RS00660': '',
#  'EQU24_RS00665': '',
#  'EQU24_RS00670': '',
#  'EQU24_RS00675': '',
#  'EQU24_RS00680': '',
#  'EQU24_RS00685': '',
#  'EQU24_RS00690': '',
#  'EQU24_RS00695': '',
#  'EQU24_RS00700': '',
#  'EQU24_RS00705': '',
#  'EQU24_RS00710': '',
#  'EQU24_RS00715': 'djlA',
#  'EQU24_RS00720': '',
#  'EQU24_RS00725': '',
#  'EQU24_RS00730': 'coaBC',
#  'EQU24_RS00735': '',
#  'EQU24_RS00740': '',
#  'EQU24_RS00745': 'argB',
#  'EQU24_RS00750': '',
#  'EQU24_RS00760': '',
#  'EQU24_RS00765': '',
#  'EQU24_RS00770': '',
#  'EQU24_RS00775': '',
#  'EQU24_RS00780': '',
#  'EQU24_RS00785': '',
#  'EQU24_RS00790': '',
#  'EQU24_RS00795': '',
#  'EQU24_RS00800': '',
#  'EQU24_RS00805': '',
#  'EQU24_RS00810': '',
#  'EQU24_RS00815': '',
#  'EQU24_RS00820': '',
#  'EQU24_RS00825': '',
#  'EQU24_RS00830': 'trpC',
#  'EQU24_RS00835': 'trpD',
#  'EQU24_RS00840': '',
#  'EQU24_RS00845': '',
#  'EQU24_RS00850': '',
#  'EQU24_RS00855': '',
#  'EQU24_RS00860': '',
#  'EQU24_RS00865': 'hemW',
#  'EQU24_RS00870': 'pyrE',
#  'EQU24_RS00875': '',
#  'EQU24_RS00880': '',
#  'EQU24_RS00885': 'trmB',
#  'EQU24_RS00890': 'thiS',
#  'EQU24_RS00895': 'aroG',
#  'EQU24_RS00900': '',
#  'EQU24_RS00905': '',
#  'EQU24_RS00910': '',
#  'EQU24_RS00915': '',
#  'EQU24_RS00920': '',
#  'EQU24_RS00925': '',
#  'EQU24_RS00930': '',
#  'EQU24_RS00940': '',
#  'EQU24_RS00945': '',
#  'EQU24_RS00950': '',
#  'EQU24_RS00955': '',
#  'EQU24_RS00960': '',
#  'EQU24_RS00965': '',
#  'EQU24_RS00970': '',
#  'EQU24_RS00975': 'mepA',
#  'EQU24_RS00980': '',
#  'EQU24_RS00985': '',
#  'EQU24_RS00990': 'aqpZ',
#  'EQU24_RS00995': '',
#  'EQU24_RS01000': '',
#  'EQU24_RS01005': '',
#  'EQU24_RS01010': '',
#  'EQU24_RS01015': '',
#  'EQU24_RS01020': '',
#  'EQU24_RS01025': '',
#  'EQU24_RS01030': '',
#  'EQU24_RS01035': '',
#  'EQU24_RS01040': '',
#  'EQU24_RS01050': '',
#  'EQU24_RS01055': '',
#  'EQU24_RS01070': '',
#  'EQU24_RS01075': '',
#  'EQU24_RS01080': '',
#  'EQU24_RS01085': '',
#  'EQU24_RS01090': '',
#  'EQU24_RS01095': '',
#  'EQU24_RS01100': '',
#  'EQU24_RS01105': '',
#  'EQU24_RS01110': '',
#  'EQU24_RS01115': '',
#  'EQU24_RS01120': '',
#  'EQU24_RS01125': '',
#  'EQU24_RS01130': '',
#  'EQU24_RS01135': '',
#  'EQU24_RS01140': '',
#  'EQU24_RS01145': '',
#  'EQU24_RS01150': '',
#  'EQU24_RS01155': '',
#  'EQU24_RS01160': '',
#  'EQU24_RS01165': '',
#  'EQU24_RS01170': '',
#  'EQU24_RS01175': 'umuD',
#  'EQU24_RS01180': '',
#  'EQU24_RS01185': '',
#  'EQU24_RS01190': '',
#  'EQU24_RS01195': '',
#  'EQU24_RS01200': '',
#  'EQU24_RS01205': '',
#  'EQU24_RS01210': '',
#  'EQU24_RS01215': '',
#  'EQU24_RS01220': '',
#  'EQU24_RS01225': '',
#  'EQU24_RS01230': '',
#  'EQU24_RS01235': '',
#  'EQU24_RS01240': '',
#  'EQU24_RS01245': '',
#  'EQU24_RS01250': '',
#  'EQU24_RS01255': '',
#  'EQU24_RS01260': '',
#  'EQU24_RS01265': '',
#  'EQU24_RS01270': '',
#  'EQU24_RS01280': '',
#  'EQU24_RS01285': '',
#  'EQU24_RS01290': '',
#  'EQU24_RS01295': '',
#  'EQU24_RS01305': '',
#  'EQU24_RS01310': '',
#  'EQU24_RS01315': '',
#  'EQU24_RS01320': '',
#  'EQU24_RS01325': '',
#  'EQU24_RS01330': '',
#  'EQU24_RS01335': '',
#  'EQU24_RS01340': '',
#  'EQU24_RS01345': '',
#  'EQU24_RS01350': '',
#  'EQU24_RS01355': '',
#  'EQU24_RS01360': '',
#  'EQU24_RS01365': '',
#  'EQU24_RS01370': '',
#  'EQU24_RS01375': '',
#  'EQU24_RS01385': 'lexA',
#  'EQU24_RS01390': '',
#  'EQU24_RS01395': '',
#  'EQU24_RS01410': '',
#  'EQU24_RS01415': '',
#  'EQU24_RS01420': '',
#  'EQU24_RS01425': '',
#  'EQU24_RS01430': '',
#  'EQU24_RS01435': '',
#  'EQU24_RS01440': '',
#  'EQU24_RS01445': '',
#  'EQU24_RS01450': '',
#  'EQU24_RS01455': '',
#  'EQU24_RS01460': 'fdhD',
#  'EQU24_RS01465': '',
#  'EQU24_RS01470': '',
#  'EQU24_RS01475': '',
#  'EQU24_RS01480': '',
#  'EQU24_RS01485': '',
#  'EQU24_RS01490': '',
#  'EQU24_RS01495': '',
#  'EQU24_RS01500': '',
#  'EQU24_RS01505': '',
#  'EQU24_RS01510': '',
#  'EQU24_RS01515': '',
#  'EQU24_RS01520': '',
#  'EQU24_RS01525': '',
#  'EQU24_RS01530': '',
#  'EQU24_RS01535': '',
#  'EQU24_RS01540': '',
#  'EQU24_RS01545': '',
#  'EQU24_RS01550': 'pssA',
#  'EQU24_RS01555': '',
#  'EQU24_RS01560': '',
#  'EQU24_RS01565': '',
#  'EQU24_RS01570': '',
#  'EQU24_RS01575': '',
#  'EQU24_RS01580': '',
#  'EQU24_RS01585': '',
#  'EQU24_RS01590': '',
#  'EQU24_RS01595': '',
#  'EQU24_RS01600': '',
#  'EQU24_RS01605': '',
#  'EQU24_RS01610': '',
#  'EQU24_RS01615': '',
#  'EQU24_RS01620': '',
#  'EQU24_RS01625': '',
#  'EQU24_RS01630': '',
#  'EQU24_RS01635': '',
#  'EQU24_RS01640': '',
#  'EQU24_RS01645': '',
#  'EQU24_RS01650': 'cysW',
#  'EQU24_RS01655': 'cysT',
#  'EQU24_RS01660': '',
#  'EQU24_RS01665': '',
#  'EQU24_RS01670': '',
#  'EQU24_RS01675': '',
#  'EQU24_RS01680': '',
#  'EQU24_RS01685': '',
#  'EQU24_RS01690': '',
#  'EQU24_RS01695': '',
#  'EQU24_RS01700': '',
#  'EQU24_RS01705': '',
#  'EQU24_RS01710': 'fabG',
#  'EQU24_RS01715': '',
#  'EQU24_RS01720': '',
#  'EQU24_RS01725': '',
#  'EQU24_RS01730': '',
#  'EQU24_RS01735': '',
#  'EQU24_RS01740': '',
#  'EQU24_RS01745': '',
#  'EQU24_RS01750': '',
#  'EQU24_RS01755': '',
#  'EQU24_RS01760': 'cydX',
#  'EQU24_RS01765': '',
#  'EQU24_RS01770': '',
#  'EQU24_RS01775': '',
#  'EQU24_RS01780': '',
#  'EQU24_RS01785': '',
#  'EQU24_RS01790': '',
#  'EQU24_RS01795': '',
#  'EQU24_RS01800': '',
#  'EQU24_RS01810': '',
#  'EQU24_RS01815': '',
#  'EQU24_RS01820': '',
#  'EQU24_RS01825': '',
#  'EQU24_RS01830': 'hflB',
#  'EQU24_RS01835': 'mscL',
#  'EQU24_RS01840': '',
#  'EQU24_RS01845': '',
#  'EQU24_RS01855': '',
#  'EQU24_RS01860': '',
#  'EQU24_RS01870': '',
#  'EQU24_RS01880': '',
#  'EQU24_RS01885': '',
#  'EQU24_RS01890': '',
#  'EQU24_RS01895': '',
#  'EQU24_RS01900': '',
#  'EQU24_RS01905': '',
#  'EQU24_RS01910': '',
#  'EQU24_RS01915': '',
#  'EQU24_RS01920': '',
#  'EQU24_RS01925': '',
#  'EQU24_RS01930': '',
#  'EQU24_RS01935': '',
#  'EQU24_RS01940': '',
#  'EQU24_RS01945': '',
#  'EQU24_RS01950': '',
#  'EQU24_RS01955': '',
#  'EQU24_RS01960': '',
#  'EQU24_RS01965': '',
#  'EQU24_RS01970': '',
#  'EQU24_RS01975': '',
#  'EQU24_RS01980': '',
#  'EQU24_RS01985': '',
#  'EQU24_RS01990': '',
#  'EQU24_RS01995': '',
#  'EQU24_RS02000': '',
#  'EQU24_RS02005': '',
#  'EQU24_RS02010': '',
#  'EQU24_RS02015': '',
#  'EQU24_RS02020': '',
#  'EQU24_RS02025': '',
#  'EQU24_RS02030': '',
#  'EQU24_RS02035': 'rdgB',
#  'EQU24_RS02040': '',
#  'EQU24_RS02045': '',
#  'EQU24_RS02050': '',
#  'EQU24_RS02055': '',
#  'EQU24_RS02060': '',
#  'EQU24_RS02065': '',
#  'EQU24_RS02070': '',
#  'EQU24_RS02075': '',
#  'EQU24_RS02080': '',
#  'EQU24_RS02085': '',
#  'EQU24_RS02090': '',
#  'EQU24_RS02100': '',
#  'EQU24_RS02105': 'rep',
#  'EQU24_RS02110': '',
#  'EQU24_RS02115': '',
#  'EQU24_RS02120': '',
#  'EQU24_RS02125': '',
#  'EQU24_RS02130': '',
#  'EQU24_RS02135': '',
#  'EQU24_RS02140': '',
#  'EQU24_RS02150': '',
#  'EQU24_RS02155': '',
#  'EQU24_RS02160': '',
#  'EQU24_RS02165': '',
#  'EQU24_RS02170': '',
#  'EQU24_RS02175': '',
#  'EQU24_RS02180': '',
#  'EQU24_RS02185': '',
#  'EQU24_RS02190': '',
#  'EQU24_RS02195': '',
#  'EQU24_RS02200': '',
#  'EQU24_RS02205': 'mnmG',
#  'EQU24_RS02210': 'rsmG',
#  'EQU24_RS02215': '',
#  'EQU24_RS02220': '',
#  'EQU24_RS02225': '',
#  'EQU24_RS02230': 'atpB',
#  'EQU24_RS02235': 'atpE',
#  'EQU24_RS02240': '',
#  'EQU24_RS02245': '',
#  'EQU24_RS02250': '',
#  'EQU24_RS02255': 'atpG',
#  'EQU24_RS02260': 'atpD',
#  'EQU24_RS02265': '',
#  'EQU24_RS02270': 'glmU',
#  'EQU24_RS02275': 'glmS',
#  'EQU24_RS02285': '',
#  'EQU24_RS02290': '',
#  'EQU24_RS02295': '',
#  'EQU24_RS02300': '',
#  'EQU24_RS02305': '',
#  'EQU24_RS02310': '',
#  'EQU24_RS02315': '',
#  'EQU24_RS02320': '',
#  'EQU24_RS02325': '',
#  'EQU24_RS02330': '',
#  'EQU24_RS02335': 'smrA',
#  'EQU24_RS02340': '',
#  'EQU24_RS02345': '',
#  'EQU24_RS02350': '',
#  'EQU24_RS02355': '',
#  'EQU24_RS02360': '',
#  'EQU24_RS02365': '',
#  'EQU24_RS02370': '',
#  'EQU24_RS02375': '',
#  'EQU24_RS02380': '',
#  'EQU24_RS02385': '',
#  'EQU24_RS02390': '',
#  'EQU24_RS02395': '',
#  'EQU24_RS02400': '',
#  'EQU24_RS02405': '',
#  'EQU24_RS02410': '',
#  'EQU24_RS02415': '',
#  'EQU24_RS02420': '',
#  'EQU24_RS02425': '',
#  'EQU24_RS02430': '',
#  'EQU24_RS02435': '',
#  'EQU24_RS02440': 'polA',
#  'EQU24_RS02445': '',
#  'EQU24_RS02450': '',
#  'EQU24_RS02455': '',
#  'EQU24_RS02460': '',
#  'EQU24_RS02465': '',
#  'EQU24_RS02470': '',
#  'EQU24_RS02475': '',
#  'EQU24_RS02485': '',
#  'EQU24_RS02490': 'thpR',
#  'EQU24_RS02495': '',
#  'EQU24_RS02500': '',
#  'EQU24_RS02505': '',
#  'EQU24_RS02510': '',
#  'EQU24_RS02515': 'tusE',
#  'EQU24_RS02520': '',
#  'EQU24_RS02525': '',
#  'EQU24_RS02530': '',
#  'EQU24_RS02535': '',
#  'EQU24_RS02540': 'ispH',
#  'EQU24_RS02545': '',
#  'EQU24_RS02550': '',
#  'EQU24_RS02555': '',
#  'EQU24_RS02560': '',
#  'EQU24_RS02565': '',
#  'EQU24_RS02570': '',
#  'EQU24_RS02575': '',
#  'EQU24_RS02580': '',
#  'EQU24_RS02585': '',
#  'EQU24_RS02590': 'nth',
#  'EQU24_RS02595': '',
#  'EQU24_RS02600': 'rsxG',
#  'EQU24_RS02605': 'rsxD',
#  'EQU24_RS02610': 'rsxC',
#  'EQU24_RS02615': 'rsxB',
#  'EQU24_RS02620': 'rsxA',
#  'EQU24_RS02625': '',
#  'EQU24_RS02630': 'gmd',
#  'EQU24_RS02635': '',
#  'EQU24_RS02640': 'secA',
#  'EQU24_RS02645': '',
#  'EQU24_RS02650': 'trmL',
#  'EQU24_RS02655': '',
#  'EQU24_RS02660': 'secB',
#  'EQU24_RS02665': '',
#  'EQU24_RS02670': '',
#  'EQU24_RS02675': '',
#  'EQU24_RS02680': '',
#  'EQU24_RS02685': '',
#  'EQU24_RS02690': '',
#  'EQU24_RS02695': '',
#  'EQU24_RS02700': '',
#  'EQU24_RS02705': '',
#  'EQU24_RS02710': '',
#  'EQU24_RS02715': 'erpA',
#  'EQU24_RS02720': '',
#  'EQU24_RS02725': '',
#  'EQU24_RS02730': '',
#  'EQU24_RS02735': '',
#  'EQU24_RS02740': '',
#  'EQU24_RS02745': '',
#  'EQU24_RS02750': '',
#  'EQU24_RS02755': '',
#  'EQU24_RS02760': '',
#  'EQU24_RS02765': '',
#  'EQU24_RS02770': '',
#  'EQU24_RS02775': '',
#  'EQU24_RS02780': '',
#  'EQU24_RS02785': '',
#  'EQU24_RS02790': '',
#  'EQU24_RS02795': '',
#  'EQU24_RS02800': 'pyrF',
#  'EQU24_RS02805': '',
#  'EQU24_RS02810': '',
#  'EQU24_RS02815': '',
#  'EQU24_RS02820': 'pdxJ',
#  'EQU24_RS02825': 'recO',
#  'EQU24_RS02830': '',
#  'EQU24_RS02835': '',
#  'EQU24_RS02840': '',
#  'EQU24_RS02845': 'lepB',
#  'EQU24_RS02850': 'lepA',
#  'EQU24_RS02855': '',
#  'EQU24_RS02860': '',
#  'EQU24_RS02865': '',
#  'EQU24_RS02870': 'rpoE',
#  'EQU24_RS02875': 'nadB',
#  'EQU24_RS02880': '',
#  'EQU24_RS02885': '',
#  'EQU24_RS02890': '',
#  'EQU24_RS02895': '',
#  'EQU24_RS02900': '',
#  'EQU24_RS02905': 'dmeF',
#  'EQU24_RS02915': '',
#  'EQU24_RS02920': '',
#  'EQU24_RS02930': '',
#  'EQU24_RS02935': 'pip',
#  'EQU24_RS02940': '',
#  'EQU24_RS02945': 'pqqE',
#  'EQU24_RS02950': 'pqqD',
#  'EQU24_RS02955': '',
#  'EQU24_RS02960': 'pqqC',
#  'EQU24_RS02965': 'pqqB',
#  'EQU24_RS02970': 'pqqA',
#  'EQU24_RS02975': '',
#  'EQU24_RS02980': '',
#  'EQU24_RS02985': '',
#  'EQU24_RS02990': '',
#  'EQU24_RS02995': '',
#  'EQU24_RS03000': '',
#  'EQU24_RS03005': '',
#  'EQU24_RS03010': '',
#  'EQU24_RS03015': '',
#  'EQU24_RS03020': '',
#  'EQU24_RS03025': 'hcp',
#  'EQU24_RS03030': '',
#  'EQU24_RS03035': 'yidD',
#  'EQU24_RS03040': '',
#  'EQU24_RS03045': '',
#  'EQU24_RS03050': '',
#  'EQU24_RS03055': '',
#  'EQU24_RS03060': '',
#  'EQU24_RS03070': '',
#  'EQU24_RS03075': 'fetB',
#  'EQU24_RS03080': '',
#  'EQU24_RS03085': '',
#  'EQU24_RS03090': '',
#  'EQU24_RS03095': '',
#  'EQU24_RS03100': '',
#  'EQU24_RS03105': '',
#  'EQU24_RS03110': '',
#  'EQU24_RS03115': 'petA',
#  'EQU24_RS03120': '',
#  'EQU24_RS03125': 'hisD',
#  'EQU24_RS03130': '',
#  'EQU24_RS03135': 'murA',
#  'EQU24_RS03140': '',
#  'EQU24_RS03145': 'mlaD',
#  'EQU24_RS03150': 'mlaE',
#  'EQU24_RS03155': '',
#  'EQU24_RS03160': '',
#  'EQU24_RS03165': '',
#  'EQU24_RS03170': 'kdsC',
#  'EQU24_RS03175': 'lptC',
#  'EQU24_RS03180': 'lptA',
#  'EQU24_RS03185': 'lptB',
#  'EQU24_RS03190': '',
#  'EQU24_RS03195': 'raiA',
#  'EQU24_RS03200': 'rapZ',
#  'EQU24_RS03205': '',
#  'EQU24_RS03210': 'minE',
#  'EQU24_RS03215': 'minD',
#  'EQU24_RS03220': 'minC',
#  'EQU24_RS03225': '',
#  'EQU24_RS03230': 'thiC',
#  'EQU24_RS03235': '',
#  'EQU24_RS03250': '',
#  'EQU24_RS03255': '',
#  'EQU24_RS03260': '',
#  'EQU24_RS03265': '',
#  'EQU24_RS03270': '',
#  'EQU24_RS03275': '',
#  'EQU24_RS03280': '',
#  'EQU24_RS03290': '',
#  'EQU24_RS03295': 'panB',
#  'EQU24_RS03300': 'folK',
#  'EQU24_RS03305': 'pcnB',
#  'EQU24_RS03310': '',
#  'EQU24_RS03315': '',
#  'EQU24_RS03320': 'lptG',
#  'EQU24_RS03325': 'lptF',
#  'EQU24_RS03330': '',
#  'EQU24_RS03335': '',
#  'EQU24_RS03340': '',
#  'EQU24_RS03345': 'pilB',
#  'EQU24_RS03350': '',
#  'EQU24_RS03355': '',
#  'EQU24_RS03360': '',
#  'EQU24_RS03365': 'zapD',
#  'EQU24_RS03370': 'yacG',
#  'EQU24_RS03375': '',
#  'EQU24_RS03380': '',
#  'EQU24_RS03385': 'grpE',
#  'EQU24_RS03390': '',
#  'EQU24_RS03395': '',
#  'EQU24_RS03400': '',
#  'EQU24_RS03405': '',
#  'EQU24_RS03415': '',
#  'EQU24_RS03420': '',
#  'EQU24_RS03425': '',
#  'EQU24_RS03435': '',
#  'EQU24_RS03440': '',
#  'EQU24_RS03445': '',
#  'EQU24_RS03450': '',
#  'EQU24_RS03455': '',
#  'EQU24_RS03460': '',
#  'EQU24_RS03465': '',
#  'EQU24_RS03470': '',
#  'EQU24_RS03475': '',
#  'EQU24_RS03480': 'glk',
#  'EQU24_RS03485': '',
#  'EQU24_RS03490': '',
#  'EQU24_RS03495': '',
#  'EQU24_RS03500': '',
#  'EQU24_RS03505': 'glyQ',
#  'EQU24_RS03510': '',
#  'EQU24_RS03515': '',
#  'EQU24_RS03520': '',
#  'EQU24_RS03525': 'lnt',
#  'EQU24_RS03535': '',
#  'EQU24_RS03540': '',
#  'EQU24_RS03545': '',
#  'EQU24_RS03550': 'ltrA',
#  'EQU24_RS03555': '',
#  'EQU24_RS03560': '',
#  'EQU24_RS03565': '',
#  'EQU24_RS03570': '',
#  'EQU24_RS03575': '',
#  'EQU24_RS03580': '',
#  'EQU24_RS03585': '',
#  'EQU24_RS03590': '',
#  'EQU24_RS03595': '',
#  'EQU24_RS03600': '',
#  'EQU24_RS03605': '',
#  'EQU24_RS03610': 'ectA',
#  'EQU24_RS03615': 'ectB',
#  'EQU24_RS03620': '',
#  'EQU24_RS03625': '',
#  'EQU24_RS03630': '',
#  'EQU24_RS03635': '',
#  'EQU24_RS03640': '',
#  'EQU24_RS03645': '',
#  'EQU24_RS03650': '',
#  'EQU24_RS03655': 'lipA',
#  'EQU24_RS03660': 'lipB',
#  'EQU24_RS03665': '',
#  'EQU24_RS03670': '',
#  'EQU24_RS03675': '',
#  'EQU24_RS03680': 'mltB',
#  'EQU24_RS03685': 'rodA',
#  'EQU24_RS03690': 'mrdA',
#  'EQU24_RS03695': 'mreD',
#  'EQU24_RS03700': 'mreC',
#  'EQU24_RS03705': '',
#  'EQU24_RS03710': 'gatC',
#  'EQU24_RS03715': 'gatA',
#  'EQU24_RS03720': '',
#  'EQU24_RS03725': 'gatB',
#  'EQU24_RS03730': '',
#  'EQU24_RS03735': '',
#  'EQU24_RS03740': 'prmC',
#  'EQU24_RS03745': 'prfA',
#  'EQU24_RS03750': '',
#  'EQU24_RS03755': '',
#  'EQU24_RS03760': 'lolB',
#  'EQU24_RS03765': 'ispE',
#  'EQU24_RS03770': '',
#  'EQU24_RS03775': '',
#  'EQU24_RS03780': '',
#  'EQU24_RS03785': '',
#  'EQU24_RS03790': '',
#  'EQU24_RS03795': '',
#  'EQU24_RS03800': 'tuf',
#  'EQU24_RS03805': '',
#  'EQU24_RS03810': 'secE',
#  'EQU24_RS03815': 'nusG',
#  'EQU24_RS03820': 'rplK',
#  'EQU24_RS03825': 'rplA',
#  'EQU24_RS03830': '',
#  'EQU24_RS03835': 'rplL',
#  'EQU24_RS03840': 'rpoB',
#  'EQU24_RS03845': 'rpoC',
#  'EQU24_RS03850': 'rpsL',
#  'EQU24_RS03855': 'rpsG',
#  'EQU24_RS03860': 'fusA',
#  'EQU24_RS03865': 'tuf',
#  'EQU24_RS03870': 'rpsJ',
#  'EQU24_RS03875': 'rplC',
#  'EQU24_RS03880': 'rplD',
#  'EQU24_RS03885': '',
#  'EQU24_RS03890': 'rplB',
#  'EQU24_RS03895': 'rpsS',
#  'EQU24_RS03900': '',
#  'EQU24_RS03905': 'rpsC',
#  'EQU24_RS03910': 'rplP',
#  'EQU24_RS03915': 'rpmC',
#  'EQU24_RS03920': 'rpsQ',
#  'EQU24_RS03925': 'rplN',
#  'EQU24_RS03930': 'rplX',
#  'EQU24_RS03935': 'rplE',
#  'EQU24_RS03940': 'rpsN',
#  'EQU24_RS03945': 'rpsH',
#  'EQU24_RS03950': 'rplF',
#  'EQU24_RS03955': '',
#  'EQU24_RS03960': '',
#  'EQU24_RS03965': 'rpmD',
#  'EQU24_RS03970': 'rplO',
#  'EQU24_RS03975': 'secY',
#  'EQU24_RS03980': 'rpmJ',
#  'EQU24_RS03985': 'rpsM',
#  'EQU24_RS03990': 'rpsK',
#  'EQU24_RS03995': 'rpsD',
#  'EQU24_RS04000': 'rpoA',
#  'EQU24_RS04005': '',
#  'EQU24_RS04010': '',
#  'EQU24_RS04015': '',
#  'EQU24_RS04020': '',
#  'EQU24_RS04025': 'sodB',
#  'EQU24_RS04030': '',
#  'EQU24_RS04035': 'moaC',
#  'EQU24_RS04040': 'moaD',
#  'EQU24_RS04045': '',
#  'EQU24_RS04050': '',
#  'EQU24_RS04055': '',
#  'EQU24_RS04060': '',
#  'EQU24_RS04065': 'ilvN',
#  'EQU24_RS04070': 'ilvC',
#  'EQU24_RS04075': 'pssA',
#  'EQU24_RS04080': '',
#  'EQU24_RS04085': '',
#  'EQU24_RS04090': 'rimI',
#  'EQU24_RS04095': '',
#  'EQU24_RS04100': '',
#  'EQU24_RS04110': '',
#  'EQU24_RS04115': '',
#  'EQU24_RS04120': '',
#  'EQU24_RS04125': '',
#  'EQU24_RS04130': 'ltrA',
#  'EQU24_RS04135': '',
#  'EQU24_RS04140': '',
#  'EQU24_RS04145': '',
#  'EQU24_RS04150': '',
#  'EQU24_RS04155': '',
#  'EQU24_RS04160': '',
#  'EQU24_RS04165': '',
#  'EQU24_RS04170': '',
#  'EQU24_RS04175': '',
#  'EQU24_RS04185': 'pepP',
#  'EQU24_RS04190': 'ubiH',
#  'EQU24_RS04195': '',
#  'EQU24_RS04200': '',
#  'EQU24_RS04205': '',
#  'EQU24_RS04210': '',
#  'EQU24_RS04215': 'sucC',
#  'EQU24_RS04220': 'sucD',
#  'EQU24_RS04225': '',
#  'EQU24_RS04230': '',
#  'EQU24_RS04235': '',
#  'EQU24_RS04240': '',
#  'EQU24_RS04245': '',
#  'EQU24_RS04250': '',
#  'EQU24_RS04255': 'rpmE',
#  'EQU24_RS04260': '',
#  'EQU24_RS04265': '',
#  'EQU24_RS04270': '',
#  'EQU24_RS04275': '',
#  'EQU24_RS04280': '',
#  'EQU24_RS04285': '',
#  'EQU24_RS04290': '',
#  'EQU24_RS04295': '',
#  'EQU24_RS04305': '',
#  'EQU24_RS04315': '',
#  'EQU24_RS04320': '',
#  'EQU24_RS04325': '',
#  'EQU24_RS04330': '',
#  'EQU24_RS04335': '',
#  'EQU24_RS04340': '',
#  'EQU24_RS04350': '',
#  'EQU24_RS04355': '',
#  'EQU24_RS04360': '',
#  'EQU24_RS04365': '',
#  'EQU24_RS04370': '',
#  'EQU24_RS04375': '',
#  'EQU24_RS04380': '',
#  'EQU24_RS04395': '',
#  'EQU24_RS04400': '',
#  'EQU24_RS04405': '',
#  'EQU24_RS04410': '',
#  'EQU24_RS04415': '',
#  'EQU24_RS04420': '',
#  'EQU24_RS04425': '',
#  'EQU24_RS04430': '',
#  'EQU24_RS04435': '',
#  'EQU24_RS04440': '',
#  'EQU24_RS04445': '',
#  'EQU24_RS04450': '',
#  'EQU24_RS04455': '',
#  'EQU24_RS04460': '',
#  'EQU24_RS04465': '',
#  'EQU24_RS04470': '',
#  'EQU24_RS04475': '',
#  'EQU24_RS04480': '',
#  'EQU24_RS04485': '',
#  'EQU24_RS04490': 'pilQ',
#  'EQU24_RS04500': 'aroK',
#  'EQU24_RS04505': 'aroB',
#  'EQU24_RS04510': '',
#  'EQU24_RS04515': 'hemE',
#  'EQU24_RS04520': '',
#  'EQU24_RS04525': '',
#  'EQU24_RS04530': '',
#  'EQU24_RS04535': '',
#  'EQU24_RS04545': 'cpsG',
#  'EQU24_RS04550': '',
#  'EQU24_RS04555': '',
#  'EQU24_RS04560': '',
#  'EQU24_RS04565': '',
#  'EQU24_RS04570': '',
#  'EQU24_RS04575': '',
#  'EQU24_RS04580': '',
#  'EQU24_RS04585': '',
#  'EQU24_RS04590': '',
#  'EQU24_RS04595': '',
#  'EQU24_RS04600': '',
#  'EQU24_RS04605': '',
#  'EQU24_RS04610': 'pilV',
#  'EQU24_RS04615': '',
#  'EQU24_RS04625': '',
#  'EQU24_RS04630': '',
#  'EQU24_RS04635': '',
#  'EQU24_RS04640': 'sucD',
#  'EQU24_RS04645': '',
#  'EQU24_RS04650': '',
#  'EQU24_RS04655': '',
#  'EQU24_RS04660': '',
#  'EQU24_RS04665': '',
#  'EQU24_RS04670': '',
#  'EQU24_RS04675': '',
#  'EQU24_RS04680': '',
#  'EQU24_RS04685': '',
#  'EQU24_RS04690': '',
#  'EQU24_RS04695': '',
#  'EQU24_RS04700': '',
#  'EQU24_RS04705': 'rsmA',
#  'EQU24_RS04710': 'pdxA',
#  'EQU24_RS04715': '',
#  'EQU24_RS04720': '',
#  'EQU24_RS04725': '',
#  'EQU24_RS04730': '',
#  'EQU24_RS04735': '',
#  'EQU24_RS04740': '',
#  'EQU24_RS04745': '',
#  'EQU24_RS04750': '',
#  'EQU24_RS04755': '',
#  'EQU24_RS04760': '',
#  'EQU24_RS04765': '',
#  'EQU24_RS04770': '',
#  'EQU24_RS04775': '',
#  'EQU24_RS04780': '',
#  'EQU24_RS04785': '',
#  'EQU24_RS04790': '',
#  'EQU24_RS04795': '',
#  'EQU24_RS04800': '',
#  'EQU24_RS04805': 'prs',
#  'EQU24_RS04810': '',
#  'EQU24_RS04815': '',
#  'EQU24_RS04820': 'bamA',
#  'EQU24_RS04825': '',
#  'EQU24_RS04830': 'fabZ',
#  'EQU24_RS04835': 'lpxA',
#  'EQU24_RS04840': 'rnhB',
#  'EQU24_RS04845': 'dnaE',
#  'EQU24_RS04850': '',
#  'EQU24_RS04855': 'rluC',
#  'EQU24_RS04860': '',
#  'EQU24_RS04865': 'sppA',
#  'EQU24_RS04870': '',
#  'EQU24_RS04875': '',
#  'EQU24_RS04880': 'radA',
#  'EQU24_RS04885': '',
#  'EQU24_RS04890': '',
#  'EQU24_RS04895': '',
#  'EQU24_RS04900': '',
#  'EQU24_RS04905': '',
#  'EQU24_RS04910': '',
#  'EQU24_RS04915': 'fliE',
#  'EQU24_RS04920': 'fliF',
#  'EQU24_RS04925': 'fliG',
#  'EQU24_RS04930': '',
#  'EQU24_RS04935': 'fliI',
#  'EQU24_RS04940': 'fliJ',
#  'EQU24_RS04945': '',
#  'EQU24_RS04950': '',
#  'EQU24_RS04955': '',
#  'EQU24_RS04960': '',
#  'EQU24_RS04965': '',
#  'EQU24_RS04970': 'msrP',
#  'EQU24_RS04975': '',
#  'EQU24_RS04980': '',
#  'EQU24_RS04985': '',
#  'EQU24_RS04990': '',
#  'EQU24_RS04995': '',
#  'EQU24_RS05000': '',
#  'EQU24_RS05005': '',
#  'EQU24_RS05010': '',
#  'EQU24_RS05015': '',
#  'EQU24_RS05020': '',
#  'EQU24_RS05025': '',
#  'EQU24_RS05030': '',
#  'EQU24_RS05035': '',
#  'EQU24_RS05040': '',
#  'EQU24_RS05045': '',
#  'EQU24_RS05050': '',
#  'EQU24_RS05055': '',
#  'EQU24_RS05060': '',
#  'EQU24_RS05065': '',
#  'EQU24_RS05070': '',
#  'EQU24_RS05075': '',
#  'EQU24_RS05080': '',
#  'EQU24_RS05085': '',
#  'EQU24_RS05090': '',
#  'EQU24_RS05095': '',
#  'EQU24_RS05100': '',
#  'EQU24_RS05105': 'gspE',
#  'EQU24_RS05110': '',
#  'EQU24_RS05115': 'gspG',
#  'EQU24_RS05120': 'gspH',
#  'EQU24_RS05125': '',
#  'EQU24_RS05130': '',
#  'EQU24_RS05135': '',
#  'EQU24_RS05140': '',
#  'EQU24_RS05145': '',
#  'EQU24_RS05150': '',
#  'EQU24_RS05155': '',
#  'EQU24_RS05160': 'gspD',
#  'EQU24_RS05165': '',
#  'EQU24_RS05170': 'nrdR',
#  'EQU24_RS05175': 'ribD',
#  'EQU24_RS05180': '',
#  'EQU24_RS05185': '',
#  'EQU24_RS05190': 'ribE',
#  'EQU24_RS05195': 'nusB',
#  ...}

# %%
df_all_gene_info_file = "../data/all_gene_info.pickle"
df_all_gene_info = pickle.load(open(df_all_gene_info_file, 'rb'))
df_all_gene_info

# %%
avg_log_ratio_tpm_file = "../data/avg_log_ratio_scaled.csv"

df_avg_log_ratio_tpm = pd.read_csv(avg_log_ratio_tpm_file).fillna('')

# %%
df_avg_log_ratio_tpm
# Out:
#           locus_tag  LanzaTech      MeOH  NO3_lowO2_slow_growth      NoCu  \
# 0     EQU24_RS00005  -0.515808 -0.012058              -0.480048 -0.163349
# 1     EQU24_RS00010   0.480568 -0.659004              -0.218643  0.075821
# 2     EQU24_RS00015  -1.072637  0.327816              -0.461533 -0.212764
# 3     EQU24_RS00020   0.723618 -1.032390               0.072132 -0.253222
# 4     EQU24_RS00025   0.424262 -0.479325               0.028098  0.116538
# ...             ...        ...       ...                    ...       ...
# 4208  EQU24_RS22135  -0.445389 -0.627550              -1.170665 -0.396450
# 4209  EQU24_RS22140   0.309593 -1.327737              -1.065740 -0.706776
# 4210  EQU24_RS22145  -1.028264 -0.395724              -1.265702 -0.657315
# 4211  EQU24_RS22150  -0.670633 -0.279756              -1.404703 -0.775605
# 4212  EQU24_RS22155  -0.665398 -1.464863              -1.306404 -0.270004
#
#       NoLanthanum  WT_control  WithLanthanum    aa3_KO  crotonic_acid  ...  \
# 0       -0.648447   -0.037469      -0.491013 -0.410117      -0.485123  ...
# 1       -0.485571   -0.114821      -0.462526  0.094641      -0.209870  ...
# 2       -0.583017   -0.648530      -0.633792 -0.917224      -0.048206  ...
# 3       -0.352283    0.183488      -0.292974  0.144541       0.167185  ...
# 4       -0.261659    0.082847      -0.454102 -0.051229       0.045575  ...
# ...           ...         ...            ...       ...            ...  ...
# 4208    -1.877416   -0.819438      -1.715711 -0.966683      -0.144739  ...
# 4209    -1.812366   -0.818297      -1.749368 -0.654022      -0.239402  ...
# 4210    -2.492508   -0.803695      -2.140667 -0.926349      -0.555916  ...
# 4211    -2.384838   -1.209018      -2.238072 -1.143556      -1.210963  ...
# 4212    -1.906208   -0.579939      -1.735955 -0.504679      -1.163303  ...
#
#       highO2_slow_growth    lowCH4     lowCu  lowO2_fast_growth  \
# 0               0.060397 -0.186470 -0.136377          -0.203679
# 1               0.504025 -0.305931  0.204399          -0.103679
# 2               0.138747 -0.385615 -0.106453           0.142845
# 3              -0.108216 -0.132304 -0.051795          -0.311922
# 4               0.450111  0.011533  0.240761          -0.573878
# ...                  ...       ...       ...                ...
# 4208           -1.123350  0.097626 -0.295041           0.153868
# 4209           -1.305006 -0.407547 -0.418638           0.243782
# 4210           -1.210127  0.079368 -0.380479           0.362696
# 4211           -1.730685  0.119592 -0.495403           0.627209
# 4212           -1.670054 -1.197919 -0.145297           0.580148
#
#       lowO2_low_iron_fast_growth  lowO2_slow_growth     medCu  slow_growth  \
# 0                      -0.487435          -0.243069  0.044174    -0.122244
# 1                      -0.283817           0.062219  0.461263     0.103303
# 2                      -0.057250          -0.235794  0.034638    -0.609406
# 3                       0.060748          -0.078771  0.169326     0.274118
# 4                       0.722346           0.029248  0.311967     0.268652
# ...                          ...                ...       ...          ...
# 4208                    0.071796          -0.825055  0.213758    -1.168263
# 4209                   -0.820586          -0.906017 -0.091223    -0.946392
# 4210                   -0.218650          -0.747930  0.020182    -0.861652
# 4211                   -0.443132          -1.002031 -0.030594    -0.961987
# 4212                   -1.489146          -0.824026  0.390702    -0.554407
#
#           uMax   unknown
# 0     0.185208 -0.620522
# 1     0.191813 -0.798028
# 2     0.158782 -0.753895
# 3     0.198566 -0.532597
# 4     0.181731 -0.011128
# ...        ...       ...
# 4208  0.206290 -0.784262
# 4209  0.229381 -1.159766
# 4210  0.229635 -1.151259
# 4211  0.233474 -1.159678
# 4212  0.233606 -1.240447
#
# [4213 rows x 21 columns]

# %% [markdown]
# ## Labels for ideal clusters

# %% [markdown]
# By Dr. Lidstrom's sanity check of the cluster composition, the two ideal clusterings that will be used are kMeans with k = 19, and BIRCH with threshold = 0.48, branching factor = 50.0, and k = 31

# %%
kmeans_19_file = "../data/cluster_by_loci/kmeans, param1 = 19, param2 = nan, param3 = nan"

df_kmeans_labels = pd.read_csv(kmeans_19_file).fillna('')
df_kmeans_labels
# Out:
#           locus_tag   0
# 0     EQU24_RS00005  12
# 1     EQU24_RS00010   4
# 2     EQU24_RS00015  17
# 3     EQU24_RS00020   4
# 4     EQU24_RS00025   4
# ...             ...  ..
# 4208  EQU24_RS22135   9
# 4209  EQU24_RS22140   9
# 4210  EQU24_RS22145   0
# 4211  EQU24_RS22150   0
# 4212  EQU24_RS22155   0
#
# [4213 rows x 2 columns]

# %%
birch_31_file = "../data/cluster_by_loci/birch, param1 = 0.48, param2 = 50.0, param3 = 31.0"

df_birch_labels = pd.read_csv(birch_31_file).fillna('')
df_birch_labels
# Out:
#           locus_tag   0
# 0     EQU24_RS00005  14
# 1     EQU24_RS00010  14
# 2     EQU24_RS00015   3
# 3     EQU24_RS00020  14
# 4     EQU24_RS00025  21
# ...             ...  ..
# 4208  EQU24_RS22135   9
# 4209  EQU24_RS22140   9
# 4210  EQU24_RS22145   9
# 4211  EQU24_RS22150   9
# 4212  EQU24_RS22155   9
#
# [4213 rows x 2 columns]

# %%
df_merged_kmeans_data = df_kmeans_labels.merge(df_avg_log_ratio_tpm, on="locus_tag")
df_merged_kmeans_data["gene_symbol"] = df_kmeans_labels['locus_tag'].apply(lambda loci : 
                                                              loci_to_gene[loci])
df_merged_kmeans_data["product"] = df_kmeans_labels['locus_tag'].apply(lambda loci : 
                                                              loci_to_product[loci])
df_merged_kmeans_data
# Out:
#           locus_tag   0  LanzaTech      MeOH  NO3_lowO2_slow_growth      NoCu  \
# 0     EQU24_RS00005  12  -0.515808 -0.012058              -0.480048 -0.163349
# 1     EQU24_RS00010   4   0.480568 -0.659004              -0.218643  0.075821
# 2     EQU24_RS00015  17  -1.072637  0.327816              -0.461533 -0.212764
# 3     EQU24_RS00020   4   0.723618 -1.032390               0.072132 -0.253222
# 4     EQU24_RS00025   4   0.424262 -0.479325               0.028098  0.116538
# ...             ...  ..        ...       ...                    ...       ...
# 4208  EQU24_RS22135   9  -0.445389 -0.627550              -1.170665 -0.396450
# 4209  EQU24_RS22140   9   0.309593 -1.327737              -1.065740 -0.706776
# 4210  EQU24_RS22145   0  -1.028264 -0.395724              -1.265702 -0.657315
# 4211  EQU24_RS22150   0  -0.670633 -0.279756              -1.404703 -0.775605
# 4212  EQU24_RS22155   0  -0.665398 -1.464863              -1.306404 -0.270004
#
#       NoLanthanum  WT_control  WithLanthanum    aa3_KO  ...     lowCu  \
# 0       -0.648447   -0.037469      -0.491013 -0.410117  ... -0.136377
# 1       -0.485571   -0.114821      -0.462526  0.094641  ...  0.204399
# 2       -0.583017   -0.648530      -0.633792 -0.917224  ... -0.106453
# 3       -0.352283    0.183488      -0.292974  0.144541  ... -0.051795
# 4       -0.261659    0.082847      -0.454102 -0.051229  ...  0.240761
# ...           ...         ...            ...       ...  ...       ...
# 4208    -1.877416   -0.819438      -1.715711 -0.966683  ... -0.295041
# 4209    -1.812366   -0.818297      -1.749368 -0.654022  ... -0.418638
# 4210    -2.492508   -0.803695      -2.140667 -0.926349  ... -0.380479
# 4211    -2.384838   -1.209018      -2.238072 -1.143556  ... -0.495403
# 4212    -1.906208   -0.579939      -1.735955 -0.504679  ... -0.145297
#
#       lowO2_fast_growth  lowO2_low_iron_fast_growth  lowO2_slow_growth  \
# 0             -0.203679                   -0.487435          -0.243069
# 1             -0.103679                   -0.283817           0.062219
# 2              0.142845                   -0.057250          -0.235794
# 3             -0.311922                    0.060748          -0.078771
# 4             -0.573878                    0.722346           0.029248
# ...                 ...                         ...                ...
# 4208           0.153868                    0.071796          -0.825055
# 4209           0.243782                   -0.820586          -0.906017
# 4210           0.362696                   -0.218650          -0.747930
# 4211           0.627209                   -0.443132          -1.002031
# 4212           0.580148                   -1.489146          -0.824026
#
#          medCu  slow_growth      uMax   unknown  gene_symbol  product
# 0     0.044174    -0.122244  0.185208 -0.620522         dnaA     dnaA
# 1     0.461263     0.103303  0.191813 -0.798028
# 2     0.034638    -0.609406  0.158782 -0.753895         recF     recF
# 3     0.169326     0.274118  0.198566 -0.532597         gyrB     gyrB
# 4     0.311967     0.268652  0.181731 -0.011128
# ...        ...          ...       ...       ...          ...      ...
# 4208  0.213758    -1.168263  0.206290 -0.784262         mnmE     mnmE
# 4209 -0.091223    -0.946392  0.229381 -1.159766         yidC     yidC
# 4210  0.020182    -0.861652  0.229635 -1.151259         yidD     yidD
# 4211 -0.030594    -0.961987  0.233474 -1.159678         rnpA     rnpA
# 4212  0.390702    -0.554407  0.233606 -1.240447         rpmH     rpmH
#
# [4213 rows x 24 columns]

# %%
df_merged_kmeans_data
# Out:
#           locus_tag  cluster_id  LanzaTech      MeOH  NO3_lowO2_slow_growth  \
# 0     EQU24_RS00005          12  -0.515808 -0.012058              -0.480048
# 1     EQU24_RS00010           4   0.480568 -0.659004              -0.218643
# 2     EQU24_RS00015          17  -1.072637  0.327816              -0.461533
# 3     EQU24_RS00020           4   0.723618 -1.032390               0.072132
# 4     EQU24_RS00025           4   0.424262 -0.479325               0.028098
# ...             ...         ...        ...       ...                    ...
# 4208  EQU24_RS22135           9  -0.445389 -0.627550              -1.170665
# 4209  EQU24_RS22140           9   0.309593 -1.327737              -1.065740
# 4210  EQU24_RS22145           0  -1.028264 -0.395724              -1.265702
# 4211  EQU24_RS22150           0  -0.670633 -0.279756              -1.404703
# 4212  EQU24_RS22155           0  -0.665398 -1.464863              -1.306404
#
#           NoCu  NoLanthanum  WT_control  WithLanthanum    aa3_KO  ...  \
# 0    -0.163349    -0.648447   -0.037469      -0.491013 -0.410117  ...
# 1     0.075821    -0.485571   -0.114821      -0.462526  0.094641  ...
# 2    -0.212764    -0.583017   -0.648530      -0.633792 -0.917224  ...
# 3    -0.253222    -0.352283    0.183488      -0.292974  0.144541  ...
# 4     0.116538    -0.261659    0.082847      -0.454102 -0.051229  ...
# ...        ...          ...         ...            ...       ...  ...
# 4208 -0.396450    -1.877416   -0.819438      -1.715711 -0.966683  ...
# 4209 -0.706776    -1.812366   -0.818297      -1.749368 -0.654022  ...
# 4210 -0.657315    -2.492508   -0.803695      -2.140667 -0.926349  ...
# 4211 -0.775605    -2.384838   -1.209018      -2.238072 -1.143556  ...
# 4212 -0.270004    -1.906208   -0.579939      -1.735955 -0.504679  ...
#
#         lowCH4     lowCu  lowO2_fast_growth  lowO2_low_iron_fast_growth  \
# 0    -0.186470 -0.136377          -0.203679                   -0.487435
# 1    -0.305931  0.204399          -0.103679                   -0.283817
# 2    -0.385615 -0.106453           0.142845                   -0.057250
# 3    -0.132304 -0.051795          -0.311922                    0.060748
# 4     0.011533  0.240761          -0.573878                    0.722346
# ...        ...       ...                ...                         ...
# 4208  0.097626 -0.295041           0.153868                    0.071796
# 4209 -0.407547 -0.418638           0.243782                   -0.820586
# 4210  0.079368 -0.380479           0.362696                   -0.218650
# 4211  0.119592 -0.495403           0.627209                   -0.443132
# 4212 -1.197919 -0.145297           0.580148                   -1.489146
#
#       lowO2_slow_growth     medCu  slow_growth      uMax   unknown  \
# 0             -0.243069  0.044174    -0.122244  0.185208 -0.620522
# 1              0.062219  0.461263     0.103303  0.191813 -0.798028
# 2             -0.235794  0.034638    -0.609406  0.158782 -0.753895
# 3             -0.078771  0.169326     0.274118  0.198566 -0.532597
# 4              0.029248  0.311967     0.268652  0.181731 -0.011128
# ...                 ...       ...          ...       ...       ...
# 4208          -0.825055  0.213758    -1.168263  0.206290 -0.784262
# 4209          -0.906017 -0.091223    -0.946392  0.229381 -1.159766
# 4210          -0.747930  0.020182    -0.861652  0.229635 -1.151259
# 4211          -1.002031 -0.030594    -0.961987  0.233474 -1.159678
# 4212          -0.824026  0.390702    -0.554407  0.233606 -1.240447
#
#       gene_symbol
# 0            dnaA
# 1
# 2            recF
# 3            gyrB
# 4
# ...           ...
# 4208         mnmE
# 4209         yidC
# 4210         yidD
# 4211         rnpA
# 4212         rpmH
#
# [4213 rows x 23 columns]

# %%
df_merged_birch_data = df_birch_labels.merge(df_avg_log_ratio_tpm, on="locus_tag")

df_merged_birch_data["gene_symbol"] = df_merged_birch_data['locus_tag'].apply(lambda loci : 
                                                              loci_to_gene[loci])

df_merged_birch_data["product"] = df_merged_birch_data['locus_tag'].apply(lambda loci : 
                                                              loci_to_product[loci])

df_merged_birch_data
# Out:
#           locus_tag   0  LanzaTech      MeOH  NO3_lowO2_slow_growth      NoCu  \
# 0     EQU24_RS00005  14  -0.515808 -0.012058              -0.480048 -0.163349
# 1     EQU24_RS00010  14   0.480568 -0.659004              -0.218643  0.075821
# 2     EQU24_RS00015   3  -1.072637  0.327816              -0.461533 -0.212764
# 3     EQU24_RS00020  14   0.723618 -1.032390               0.072132 -0.253222
# 4     EQU24_RS00025  21   0.424262 -0.479325               0.028098  0.116538
# ...             ...  ..        ...       ...                    ...       ...
# 4208  EQU24_RS22135   9  -0.445389 -0.627550              -1.170665 -0.396450
# 4209  EQU24_RS22140   9   0.309593 -1.327737              -1.065740 -0.706776
# 4210  EQU24_RS22145   9  -1.028264 -0.395724              -1.265702 -0.657315
# 4211  EQU24_RS22150   9  -0.670633 -0.279756              -1.404703 -0.775605
# 4212  EQU24_RS22155   9  -0.665398 -1.464863              -1.306404 -0.270004
#
#       NoLanthanum  WT_control  WithLanthanum    aa3_KO  ...     lowCu  \
# 0       -0.648447   -0.037469      -0.491013 -0.410117  ... -0.136377
# 1       -0.485571   -0.114821      -0.462526  0.094641  ...  0.204399
# 2       -0.583017   -0.648530      -0.633792 -0.917224  ... -0.106453
# 3       -0.352283    0.183488      -0.292974  0.144541  ... -0.051795
# 4       -0.261659    0.082847      -0.454102 -0.051229  ...  0.240761
# ...           ...         ...            ...       ...  ...       ...
# 4208    -1.877416   -0.819438      -1.715711 -0.966683  ... -0.295041
# 4209    -1.812366   -0.818297      -1.749368 -0.654022  ... -0.418638
# 4210    -2.492508   -0.803695      -2.140667 -0.926349  ... -0.380479
# 4211    -2.384838   -1.209018      -2.238072 -1.143556  ... -0.495403
# 4212    -1.906208   -0.579939      -1.735955 -0.504679  ... -0.145297
#
#       lowO2_fast_growth  lowO2_low_iron_fast_growth  lowO2_slow_growth  \
# 0             -0.203679                   -0.487435          -0.243069
# 1             -0.103679                   -0.283817           0.062219
# 2              0.142845                   -0.057250          -0.235794
# 3             -0.311922                    0.060748          -0.078771
# 4             -0.573878                    0.722346           0.029248
# ...                 ...                         ...                ...
# 4208           0.153868                    0.071796          -0.825055
# 4209           0.243782                   -0.820586          -0.906017
# 4210           0.362696                   -0.218650          -0.747930
# 4211           0.627209                   -0.443132          -1.002031
# 4212           0.580148                   -1.489146          -0.824026
#
#          medCu  slow_growth      uMax   unknown  gene_symbol  product
# 0     0.044174    -0.122244  0.185208 -0.620522         dnaA     dnaA
# 1     0.461263     0.103303  0.191813 -0.798028
# 2     0.034638    -0.609406  0.158782 -0.753895         recF     recF
# 3     0.169326     0.274118  0.198566 -0.532597         gyrB     gyrB
# 4     0.311967     0.268652  0.181731 -0.011128
# ...        ...          ...       ...       ...          ...      ...
# 4208  0.213758    -1.168263  0.206290 -0.784262         mnmE     mnmE
# 4209 -0.091223    -0.946392  0.229381 -1.159766         yidC     yidC
# 4210  0.020182    -0.861652  0.229635 -1.151259         yidD     yidD
# 4211 -0.030594    -0.961987  0.233474 -1.159678         rnpA     rnpA
# 4212  0.390702    -0.554407  0.233606 -1.240447         rpmH     rpmH
#
# [4213 rows x 24 columns]

# %%
x = list(df_merged_kmeans_data.columns)
x[1] = "cluster_id"
df_merged_kmeans_data.columns = x
df_merged_birch_data.columns = x

df_merged_birch_data
df_merged_kmeans_data
# Out:
#           locus_tag  cluster_id  LanzaTech      MeOH  NO3_lowO2_slow_growth  \
# 0     EQU24_RS00005          12  -0.515808 -0.012058              -0.480048
# 1     EQU24_RS00010           4   0.480568 -0.659004              -0.218643
# 2     EQU24_RS00015          17  -1.072637  0.327816              -0.461533
# 3     EQU24_RS00020           4   0.723618 -1.032390               0.072132
# 4     EQU24_RS00025           4   0.424262 -0.479325               0.028098
# ...             ...         ...        ...       ...                    ...
# 4208  EQU24_RS22135           9  -0.445389 -0.627550              -1.170665
# 4209  EQU24_RS22140           9   0.309593 -1.327737              -1.065740
# 4210  EQU24_RS22145           0  -1.028264 -0.395724              -1.265702
# 4211  EQU24_RS22150           0  -0.670633 -0.279756              -1.404703
# 4212  EQU24_RS22155           0  -0.665398 -1.464863              -1.306404
#
#           NoCu  NoLanthanum  WT_control  WithLanthanum    aa3_KO  ...  \
# 0    -0.163349    -0.648447   -0.037469      -0.491013 -0.410117  ...
# 1     0.075821    -0.485571   -0.114821      -0.462526  0.094641  ...
# 2    -0.212764    -0.583017   -0.648530      -0.633792 -0.917224  ...
# 3    -0.253222    -0.352283    0.183488      -0.292974  0.144541  ...
# 4     0.116538    -0.261659    0.082847      -0.454102 -0.051229  ...
# ...        ...          ...         ...            ...       ...  ...
# 4208 -0.396450    -1.877416   -0.819438      -1.715711 -0.966683  ...
# 4209 -0.706776    -1.812366   -0.818297      -1.749368 -0.654022  ...
# 4210 -0.657315    -2.492508   -0.803695      -2.140667 -0.926349  ...
# 4211 -0.775605    -2.384838   -1.209018      -2.238072 -1.143556  ...
# 4212 -0.270004    -1.906208   -0.579939      -1.735955 -0.504679  ...
#
#          lowCu  lowO2_fast_growth  lowO2_low_iron_fast_growth  \
# 0    -0.136377          -0.203679                   -0.487435
# 1     0.204399          -0.103679                   -0.283817
# 2    -0.106453           0.142845                   -0.057250
# 3    -0.051795          -0.311922                    0.060748
# 4     0.240761          -0.573878                    0.722346
# ...        ...                ...                         ...
# 4208 -0.295041           0.153868                    0.071796
# 4209 -0.418638           0.243782                   -0.820586
# 4210 -0.380479           0.362696                   -0.218650
# 4211 -0.495403           0.627209                   -0.443132
# 4212 -0.145297           0.580148                   -1.489146
#
#       lowO2_slow_growth     medCu  slow_growth      uMax   unknown  \
# 0             -0.243069  0.044174    -0.122244  0.185208 -0.620522
# 1              0.062219  0.461263     0.103303  0.191813 -0.798028
# 2             -0.235794  0.034638    -0.609406  0.158782 -0.753895
# 3             -0.078771  0.169326     0.274118  0.198566 -0.532597
# 4              0.029248  0.311967     0.268652  0.181731 -0.011128
# ...                 ...       ...          ...       ...       ...
# 4208          -0.825055  0.213758    -1.168263  0.206290 -0.784262
# 4209          -0.906017 -0.091223    -0.946392  0.229381 -1.159766
# 4210          -0.747930  0.020182    -0.861652  0.229635 -1.151259
# 4211          -1.002031 -0.030594    -0.961987  0.233474 -1.159678
# 4212          -0.824026  0.390702    -0.554407  0.233606 -1.240447
#
#       gene_symbol  product
# 0            dnaA     dnaA
# 1
# 2            recF     recF
# 3            gyrB     gyrB
# 4
# ...           ...      ...
# 4208         mnmE     mnmE
# 4209         yidC     yidC
# 4210         yidD     yidD
# 4211         rnpA     rnpA
# 4212         rpmH     rpmH
#
# [4213 rows x 24 columns]

# %% [markdown]
# ## GO Terms For Loci

# %%
blast_2_go_file = "../data/go_terms/blast_2_go"

df_go_terms = pd.read_csv("../data/go_terms/blast_2_go").fillna('')
df_go_terms
# Out:
#                loci                                           go_terms
# 0     EQU24_RS00005  ['GO:0003688', 'GO:0005524', 'GO:0005737', 'GO...
# 1     EQU24_RS00010  ['GO:0003677', 'GO:0003887', 'GO:0005737', 'GO...
# 2     EQU24_RS00015  ['GO:0003697', 'GO:0005524', 'GO:0005737', 'GO...
# 3     EQU24_RS00020  ['GO:0003677', 'GO:0003918', 'GO:0005524', 'GO...
# 4     EQU24_RS00040                       ['GO:0015562', 'GO:0055085']
# ...             ...                                                ...
# 3406  EQU24_RS22135  ['GO:0003924', 'GO:0005515', 'GO:0005525', 'GO...
# 3407  EQU24_RS22140  ['GO:0005886', 'GO:0015031', 'GO:0016021', 'GO...
# 3408  EQU24_RS22145                                     ['GO:0005886']
# 3409  EQU24_RS22150  ['GO:0000049', 'GO:0001682', 'GO:0004526', 'GO...
# 3410  EQU24_RS22155         ['GO:0003735', 'GO:0005840', 'GO:0006412']
#
# [3411 rows x 2 columns]

# %% [markdown]
# # Parallel Coordinate Plot

# %% [markdown]
# ## Key Functions:
#
# - Author: Erin
# - Modified for Use: Vrishab

# %%
def altair_pcoords(df,title,xorder='exp_condition_order'):
    # If more than 30 entries, make 2 columns
    col_num = 1 if len(df['locus_tag'].unique()) <=50 else 2
    
    highlight = alt.selection(type='single', on='mouseover',
                              fields=['desc_string'], nearest=True)
    
    selection = alt.selection_multi(fields=['desc_string'], bind='legend')


    base = alt.Chart(df.sort_values(xorder),
                     title=title
        ).encode(
        x=alt.X(f'{xorder}:N',
                sort=alt.EncodingSortField(field=f"{xorder}:N", op="count")
               ),
        y='mean:Q',
        color=alt.Color('desc_string:N',
                        legend=alt.Legend(title='Gene', 
                                          orient = 'right',
                                          labelLimit=0,
                                          columns=col_num,
                                          symbolLimit=200
                                         )),
        size=alt.value(100)        
    )
    

    lines = base.mark_line().encode(
        size=alt.condition((selection|highlight), alt.value(3), alt.value(1)),
        opacity=alt.condition((selection|highlight), alt.value(1), alt.value(0.5))
    ).add_selection(
        selection,
    ).properties(
         width=600,
         height=400
    ).interactive()
    
    
    points = base.mark_circle().encode(
        tooltip=['locus_tag','product','type','gene_symbol'],
        opacity=alt.condition((selection|highlight), alt.value(1), alt.value(0.2)),
        size=alt.condition((selection|highlight), alt.value(100), alt.value(3))
    ).add_selection(highlight)

    #return points + lines
    return lines + points

def check_cluster_expression(df, cols,cluster_id,title):
    df['desc_string'] = df.apply(lambda row: f"{row['locus_tag']}|{row['gene_symbol']}|{row['product']}",axis=1)
    id_vars = ['locus_tag','gene_symbol','product','cluster_id','desc_string']
    dfm = df.melt(id_vars=id_vars, value_vars=cols,var_name='exp_condition',value_name="mean")
    # altair sort helper
    list_ordering = conditions
    dfm["exp_condition_order"] = pd.Categorical(dfm["exp_condition"], categories=list_ordering)
    return dfm
    #return altair_pcoords(dfm[dfm['cluster_id']==cluster_id],title)

# %%
check_cluster_expression(
    df_merged_kmeans_data, 
    
    conditions,
    2,
    "norm nocu subset, cluster 13")
id_vars = ['locus_tag']
dfm = df.melt(id_vars=id_vars, value_vars=cols,var_name='exp_condition',value_name="mean")
# altair sort helper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-20e45fc632c3> in <module>
#       6     "norm nocu subset, cluster 13")
#       7 id_vars = ['locus_tag']
# ----> 8 dfm = df.melt(id_vars=id_vars, value_vars=cols,var_name='exp_condition',value_name="mean")
#       9 # altair sort helper
#
# NameError: name 'df' is not defined

# %%
check_cluster_expression(
    df_merged_birch_data, 
    conditions,
    2,
    "norm nocu subset, cluster 13")
# Out:
#            locus_tag gene_symbol product  cluster_id              desc_string  \
# 0      EQU24_RS00005        dnaA    dnaA          14  EQU24_RS00005|dnaA|dnaA
# 1      EQU24_RS00010                              14          EQU24_RS00010||
# 2      EQU24_RS00015        recF    recF           3  EQU24_RS00015|recF|recF
# 3      EQU24_RS00020        gyrB    gyrB          14  EQU24_RS00020|gyrB|gyrB
# 4      EQU24_RS00025                              21          EQU24_RS00025||
# ...              ...         ...     ...         ...                      ...
# 84255  EQU24_RS22135        mnmE    mnmE           9  EQU24_RS22135|mnmE|mnmE
# 84256  EQU24_RS22140        yidC    yidC           9  EQU24_RS22140|yidC|yidC
# 84257  EQU24_RS22145        yidD    yidD           9  EQU24_RS22145|yidD|yidD
# 84258  EQU24_RS22150        rnpA    rnpA           9  EQU24_RS22150|rnpA|rnpA
# 84259  EQU24_RS22155        rpmH    rpmH           9  EQU24_RS22155|rpmH|rpmH
#
#       exp_condition      mean exp_condition_order
# 0            highCu  0.085206              highCu
# 1            highCu  0.873114              highCu
# 2            highCu  0.220238              highCu
# 3            highCu  0.346152              highCu
# 4            highCu  0.265104              highCu
# ...             ...       ...                 ...
# 84255          NoCu -0.396450                NoCu
# 84256          NoCu -0.706776                NoCu
# 84257          NoCu -0.657315                NoCu
# 84258          NoCu -0.775605                NoCu
# 84259          NoCu -0.270004                NoCu
#
# [84260 rows x 8 columns]

# %% [markdown]
# # Practice

# %%
condition_to_ferm_run_file = "../data/new_sample2condition.txt"



    
# load mapping from sample to condition
with open(condition_to_loci_file,'r') as f:
    loci_to_ferm_run = str(f.readline()[1:(len(f.readline())-1)]).split(',')

    loci_tracker = dict(loci.replace('"', "").strip().split(':') for loci in loci_to_condition)
    
condition_to_ferm_run = {}
    
for exp_run in loci_tracker.keys(): 
    
    cur_condition = loci_tracker[exp_run].strip()
    
    if cur_condition not in condition_to_ferm_run.keys():
        condition_to_ferm_run[cur_condition] = [exp_run]
        print(cur_condition)
        print(condition_to_ferm_run)
        print(condition_to_ferm_run[cur_condition])

        print("BB")
        
    else: 
        condition_to_ferm_run[cur_condition] = condition_to_ferm_run[cur_condition].append(exp_run)


        print(cur_condition)
        print(condition_to_ferm_run[cur_condition])
        print(condition_to_ferm_run)
        print("AA")
    
# df_loci_tracker = pd.DataFrame(loci_tracker.keys(), loci_tracker.values()).reset_index()
# df_loci_tracker.columns = ["condition", "exp_run"]
condition_to_ferm_run
# Out:
# lowO2_slow_growth
# {'lowO2_slow_growth': ['5GB1_ferm_Ack_QC_tpm']}
# ['5GB1_ferm_Ack_QC_tpm']
# BB
# lowO2_slow_growth
# None
# {'lowO2_slow_growth': None}
# AA
# uMax
# {'lowO2_slow_growth': None, 'uMax': ['5GB1_FM03_TR1_QC_tpm']}
# ['5GB1_FM03_TR1_QC_tpm']
# BB
# uMax
# None
# {'lowO2_slow_growth': None, 'uMax': None}
# AA
# lowO2_low_iron_fast_growth
# {'lowO2_slow_growth': None, 'uMax': None, 'lowO2_low_iron_fast_growth': ['5GB1_FM11_TR1_QC_tpm']}
# ['5GB1_FM11_TR1_QC_tpm']
# BB
# lowO2_low_iron_fast_growth
# None
# {'lowO2_slow_growth': None, 'uMax': None, 'lowO2_low_iron_fast_growth': None}
# AA
# lowCH4
# {'lowO2_slow_growth': None, 'uMax': None, 'lowO2_low_iron_fast_growth': None, 'lowCH4': ['5GB1_FM12_TR1_tpm']}
# ['5GB1_FM12_TR1_tpm']
# BB
# lowCH4
# None
# {'lowO2_slow_growth': None, 'uMax': None, 'lowO2_low_iron_fast_growth': None, 'lowCH4': None}
# AA
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-d374e4596e6f> in <module>
#      23
#      24     else:
# ---> 25         condition_to_ferm_run[cur_condition] = condition_to_ferm_run[cur_condition].append(exp_run)
#      26
#      27
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
len(set(df_avg_log_ratio_tpm['locus_tag']).intersection(set(df_kmeans_labels['locus_tag'])))
# Out:
# 4213
