# %% [markdown]
# # Notebook for analyzing expression of diagnostic genes in rnaSeq tpm data for 5GB1 bacteria
#
# Collaborators:
# * Vrishabhadev Sathish Kumar
# * PI: Erin Wilson
#
# Data files:
# * RNA-seq output from barrelseq pipeline
# * mapping from sample id to experiment condition
# * diagnostic genes identified by Dr. Lidstrom

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import copy as cp
import math

# %%
# load TPM data
tpm_data_file = 'data/TPM_counts.tsv'
sample2condition_file = 'data/sample2condition.txt'
diagnostic_genes_file = 'data/diagnostic_genes.csv'
unstable_diag_genes_file = 'data/unstable_diagnostic_expression.csv'

# load TPM data
df = pd.read_csv(tpm_data_file,sep='\t').fillna('')

# Parse and obtain usable dataframe of raw tpm
df_raw_tpm = df.iloc[:, 10:].T
loci = df["locus_tag"]
df_raw_tpm = df_raw_tpm.set_axis(loci, axis = 1)

    
# load mapping from sample to condition
with open(sample2condition_file,'r') as f:
    sample2condition = dict(x.strip().split() for x in f.readlines())

    
# load the diagnostic genes data
df_diagnostics = pd.read_csv(diagnostic_genes_file)

# load the unstable diagnostic genes data
df_unstable_diag_samples = pd.read_csv(unstable_diag_genes_file)

# %%
df_raw_tpm
# Out:
# locus_tag              EQU24_RS00005  EQU24_RS00010  EQU24_RS00015  \
# 5GB1_ferm_Ack_QC_tpm        2.933003       1.607784       1.415515
# 5GB1_ferm_WT_QC_tpm         6.033848       3.895284       2.549771
# 5GB1_FM03_TR1_QC_tpm       48.864921      51.315629      33.906257
# 5GB1_FM03_TR2_QC_tpm       52.197450      54.947425      29.979783
# 5GB1_FM11_TR1_QC_tpm       25.751902      37.216017      21.716802
# ...                              ...            ...            ...
# 5GB1C-5G-N-BR2_tpm         33.432274      48.142385      22.006566
# 5GB1C-JG15-La-BR1_tpm      39.880174      45.465136      22.658157
# 5GB1C-JG15-La-BR2_tpm      38.355431      46.498139      22.753325
# 5GB1C-JG15-N-BR1_tpm       30.247582      37.152951      19.407103
# 5GB1C-JG15-N-BR2_tpm       41.248441      52.902410      29.834124
#
# locus_tag              EQU24_RS00020  EQU24_RS00025  EQU24_RS00030  \
# 5GB1_ferm_Ack_QC_tpm        3.200081       1.522728       2.013385
# 5GB1_ferm_WT_QC_tpm         4.301580       3.797084       1.694449
# 5GB1_FM03_TR1_QC_tpm       64.584281      74.801354      13.090237
# 5GB1_FM03_TR2_QC_tpm       72.717824      62.709260      24.874673
# 5GB1_FM11_TR1_QC_tpm       53.032824      46.348014      42.426259
# ...                              ...            ...            ...
# 5GB1C-5G-N-BR2_tpm         64.648318      39.358066      34.654512
# 5GB1C-JG15-La-BR1_tpm      69.119079      38.992158      67.033753
# 5GB1C-JG15-La-BR2_tpm      65.643179      35.870964      51.959561
# 5GB1C-JG15-N-BR1_tpm       57.590223      41.462392      44.527488
# 5GB1C-JG15-N-BR2_tpm       68.306759      40.227192      55.483544
#
# locus_tag              EQU24_RS00035  EQU24_RS00040  EQU24_RS00045  \
# 5GB1_ferm_Ack_QC_tpm        8.890269       1.632474       0.790911
# 5GB1_ferm_WT_QC_tpm         9.506517       3.340407       2.160868
# 5GB1_FM03_TR1_QC_tpm       50.320911      20.811187      21.910217
# 5GB1_FM03_TR2_QC_tpm       71.255094      19.773190      19.421485
# 5GB1_FM11_TR1_QC_tpm       58.772307       9.667881       8.212313
# ...                              ...            ...            ...
# 5GB1C-5G-N-BR2_tpm        107.541275      33.869275      23.770815
# 5GB1C-JG15-La-BR1_tpm     130.729298      39.968258      22.454067
# 5GB1C-JG15-La-BR2_tpm     120.575354      37.092594      20.769383
# 5GB1C-JG15-N-BR1_tpm      105.320613      27.798238      18.873435
# 5GB1C-JG15-N-BR2_tpm      149.614937      36.105449      19.384364
#
# locus_tag              EQU24_RS00050  ...  EQU24_RS22110  EQU24_RS22115  \
# 5GB1_ferm_Ack_QC_tpm        0.446398  ...     170.826337       0.973237
# 5GB1_ferm_WT_QC_tpm         1.134421  ...     259.349616       2.866741
# 5GB1_FM03_TR1_QC_tpm       18.096708  ...    6655.778183      56.948463
# 5GB1_FM03_TR2_QC_tpm       16.776993  ...    6480.237054      50.243190
# 5GB1_FM11_TR1_QC_tpm       12.634273  ...    6651.883413      25.635202
# ...                              ...  ...            ...            ...
# 5GB1C-5G-N-BR2_tpm         20.064562  ...    9003.930101      20.600870
# 5GB1C-JG15-La-BR1_tpm      18.039069  ...    3318.767885      10.724405
# 5GB1C-JG15-La-BR2_tpm      17.655632  ...    3458.558649      15.496249
# 5GB1C-JG15-N-BR1_tpm       15.578396  ...    3997.726513      17.356475
# 5GB1C-JG15-N-BR2_tpm       18.238881  ...    5036.338937      17.721464
#
# locus_tag              EQU24_RS22120  EQU24_RS22125  EQU24_RS22130  \
# 5GB1_ferm_Ack_QC_tpm        2.344352       2.331287       4.867523
# 5GB1_ferm_WT_QC_tpm         1.856930       0.951269       3.972334
# 5GB1_FM03_TR1_QC_tpm       52.002311      60.628466      23.015801
# 5GB1_FM03_TR2_QC_tpm       41.376658      66.581832      54.669612
# 5GB1_FM11_TR1_QC_tpm       29.059082      59.545627      34.189659
# ...                              ...            ...            ...
# 5GB1C-5G-N-BR2_tpm         37.114422      39.499880      42.467068
# 5GB1C-JG15-La-BR1_tpm      39.422680      49.109710      46.810258
# 5GB1C-JG15-La-BR2_tpm      41.910716      53.086286      44.827579
# 5GB1C-JG15-N-BR1_tpm       41.685308      44.836637      47.307203
# 5GB1C-JG15-N-BR2_tpm       45.872297      45.303552      38.774423
#
# locus_tag              EQU24_RS22135  EQU24_RS22140  EQU24_RS22145  \
# 5GB1_ferm_Ack_QC_tpm        2.300157       5.261582       9.389775
# 5GB1_ferm_WT_QC_tpm         3.217944      12.526353      21.072962
# 5GB1_FM03_TR1_QC_tpm      104.488835     379.686212     500.129230
# 5GB1_FM03_TR2_QC_tpm      103.864151     401.742811     495.262554
# 5GB1_FM11_TR1_QC_tpm       78.264069     208.094267     260.011454
# ...                              ...            ...            ...
# 5GB1C-5G-N-BR2_tpm         30.766617     166.101675      59.523445
# 5GB1C-JG15-La-BR1_tpm      22.101468      96.169044      47.641158
# 5GB1C-JG15-La-BR2_tpm      19.753259      93.527806      60.667488
# 5GB1C-JG15-N-BR1_tpm       20.027390      89.780995      55.739018
# 5GB1C-JG15-N-BR2_tpm       24.508375     130.851229      66.415222
#
# locus_tag              EQU24_RS22150  EQU24_RS22155
# 5GB1_ferm_Ack_QC_tpm       21.657488      27.832080
# 5GB1_ferm_WT_QC_tpm        42.254357      41.530602
# 5GB1_FM03_TR1_QC_tpm     1191.565348     796.964423
# 5GB1_FM03_TR2_QC_tpm     1232.784967     724.291958
# 5GB1_FM11_TR1_QC_tpm      666.589153     461.697526
# ...                              ...            ...
# 5GB1C-5G-N-BR2_tpm        259.828426     404.714461
# 5GB1C-JG15-La-BR1_tpm     134.795621     265.487592
# 5GB1C-JG15-La-BR2_tpm     160.260255     308.428817
# 5GB1C-JG15-N-BR1_tpm      174.197473     286.670085
# 5GB1C-JG15-N-BR2_tpm      164.123473     301.751157
#
# [98 rows x 4213 columns]

# %%
list_conditions = list(set(sample2condition.values()))
list_conditions
# Out:
# ['WithLanthanum',
#  'highCu',
#  'crotonic_acid',
#  'NoCu',
#  'LanzaTech',
#  'lowO2_fast_growth',
#  'MeOH',
#  'slow_growth',
#  'aa3_KO',
#  'NO3_lowO2_slow_growth',
#  'lowO2_slow_growth',
#  'highO2_slow_growth',
#  'lowCu',
#  'uMax',
#  'lowCH4',
#  'unknown',
#  'medCu',
#  'WT_control',
#  'NoLanthanum']

# %%
# Represents a list of all samples for each experimental condition
condition_to_sample = dict((condition,[]) for condition in list_conditions)

for sample in sample2condition.keys():
    condition_to_sample[sample2condition[sample]].append(sample)
    
condition_to_sample
# Out:
# {'WithLanthanum': ['5GB1_vial_wLa_TR3_tpm',
#   '5GB1C-5G-La-BR1_tpm',
#   '5GB1C-5G-La-BR2_tpm',
#   '5GB1C-JG15-La-BR1_tpm',
#   '5GB1C-JG15-La-BR2_tpm'],
#  'highCu': ['5GB1_FM34_T4_TR3_QC_tpm',
#   '5GB1_FM34_T5_TR2_QC_tpm',
#   '5GB1_FM34_T6_TR3_QC_tpm',
#   '5GB1_FM34_T7_TR3_QC_tpm',
#   '5GB1_FM34_T8_TR1_QC_tpm'],
#  'crotonic_acid': ['5GB1_pA9_red_tpm', '5GB1_pA9_yellow_tpm'],
#  'NoCu': ['5GB1_FM34_T0_TR1_QC_tpm',
#   '5GB1_FM40_T0_TR1_QC_tpm',
#   '5GB1_FM40_T0m_TR2_tpm'],
#  'LanzaTech': ['5GB1_LTrecycle_TR1_tpm', '5GB1_LTrecycle_TR1_QC_tpm'],
#  'lowO2_fast_growth': ['5GB1_FM11_TR1_QC_tpm',
#   '5GB1_FM11_TR2_QC_tpm',
#   '5GB1_FM19_TR1_tpm',
#   '5GB1_FM19_TR1_QC_tpm',
#   '5GB1_FM19_TR1_UW_tpm',
#   '5GB1_FM19_TR3_tpm',
#   '5GB1_FM19_TR3_QC_tpm',
#   '5GB1_FM22_TR1_tpm',
#   '5GB1_FM22_TR1_QC_tpm',
#   '5GB1_FM22_TR3_tpm',
#   '5GB1_FM22_TR3_QC_tpm',
#   '5GB1_FM22_TR3_UW_tpm'],
#  'MeOH': ['5GB1_FM18_TR1_QC_tpm',
#   '5GB1_FM18_TR2_tpm',
#   '5GB1_FM18_TR2_QC_tpm',
#   '5GB1_FM18_TR3_tpm',
#   '5GB1_FM18_TR3_QC_tpm',
#   '5GB1_FM23_TR3_tpm',
#   '5GB1_FM23_TR3_QC_tpm'],
#  'slow_growth': ['5GB1_FM58_Td20h_TR1_QC_tpm', '5GB1_FM58_Td32h_TR3_QC_tpm'],
#  'aa3_KO': ['5GB1_FM_85_TR1_tpm', '5GB1_FM_85_TR2_tpm'],
#  'NO3_lowO2_slow_growth': ['5GB1_FM80_t2_TR1_tpm',
#   '5GB1_FM80_t4_TR1_tpm',
#   '5GB1_FM81_t1_TR3_tpm',
#   '5GB1_FM81_t2_TR3_tpm'],
#  'lowO2_slow_growth': ['5GB1_ferm_Ack_QC_tpm',
#   '5GB1_ferm_WT_QC_tpm',
#   '5GB1_FM69_t2_TR1_tpm'],
#  'highO2_slow_growth': ['5GB1_FM69_t3_TR1_tpm',
#   '5GB1_FM69_t3_TR1_UW_tpm',
#   '5GB1_FM69_t4_TR1_tpm',
#   '5GB1_FM69_t4_TR1_UW_tpm'],
#  'lowCu': ['5GB1_FM40_T10m_TR3_tpm',
#   '5GB1_FM40_T10m_TR3_QC_tpm',
#   '5GB1_FM40_T20m_TR2_tpm',
#   '5GB1_FM40_T20m_TR2_QC_tpm',
#   '5GB1_FM40_T40m_TR1_tpm',
#   '5GB1_FM40_T40m_TR1_QC_tpm',
#   '5GB1_FM40_T60m_TR1_tpm',
#   '5GB1_FM40_T60m_TR1_QC_tpm'],
#  'uMax': ['5GB1_FM03_TR1_QC_tpm',
#   '5GB1_FM03_TR2_QC_tpm',
#   '5GB1_FM20_TR1_QC_tpm',
#   '5GB1_FM20_TR2_QC_tpm',
#   '5GB1_FM20_TR3_tpm',
#   '5GB1_FM20_TR3_QC_tpm',
#   '5GB1_FM20_TR3_UW_tpm',
#   '5GB1_FM21_TR1_tpm',
#   '5GB1_FM21_TR1_QC_tpm',
#   '5GB1_FM21_TR2_tpm',
#   '5GB1_FM21_TR2_QC_tpm',
#   '5GB1_FM21_TR2_UW_tpm'],
#  'lowCH4': ['5GB1_FM12_TR1_tpm',
#   '5GB1_FM12_TR1_QC_tpm',
#   '5GB1_FM12_TR2_tpm',
#   '5GB1_FM12_TR2_QC_tpm',
#   '5GB1_FM14_TR1_tpm',
#   '5GB1_FM14_TR1_QC_tpm',
#   '5GB1_FM14_TR2_tpm',
#   '5GB1_FM14_TR2_QC_tpm'],
#  'unknown': ['5GB1C_latelog_vial_TR2_QC_tpm',
#   'br1_QC_tpm',
#   'br2_QC_tpm',
#   'ribo0_tpm',
#   'total_tpm'],
#  'medCu': ['5GB1_FM34_T3_TR3_QC_tpm',
#   '5GB1_FM40_T150m_TR1_QC_tpm',
#   '5GB1_FM40_T150m_TR1_remake_tpm',
#   '5GB1_FM40_T180m_TR1_tpm',
#   '5GB1_FM40_T180m_TR1_QC_tpm',
#   '5GB1_FM40_T90m_TR2_tpm',
#   '5GB1_FM40_T90m_TR2_QC_tpm'],
#  'WT_control': ['5GB1_FM_86_TR1_tpm', '5GB1_FM_87_TR1_tpm'],
#  'NoLanthanum': ['5GB1_vial_woLa_TR2_tpm',
#   '5GB1C-5G-N-BR1_tpm',
#   '5GB1C-5G-N-BR2_tpm',
#   '5GB1C-JG15-N-BR1_tpm',
#   '5GB1C-JG15-N-BR2_tpm']}

# %% [markdown]
# ***
# # Functions:

# %% [markdown]
# ## PairPlots  --> For each experimental condition

# %%
def plot_diagonal(xdata, ydata, **kws):
    mx = xdata.max() + 15
    plt.plot([0,mx],[0,mx], color = "black", lw = 0.7, linestyle = "--", label = "Diagonal (for comparison)")

# %%
def plot_cloud(xdata, ydata, **kws):
    s1_name =  "5GB1_FM20_TR3_tpm" # Unflagged Exception
    s2_name = "5GB1_FM20_TR3_UW_tpm"  # Correlated with major

    plt.figure(figsize=(13, 12))


    s1 = df_raw_tpm.T[s1_name] + 0.01
    s2 = df_raw_tpm.T[s2_name] + 0.01

    max_length = 20
    ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, alpha = 0.02)

# %%
def sample_pairwise_scatter(df_diag_samples, title, filename):
    labels = list(gene_to_diagnostic.values()) #df_diag_samples["locus_tag"]
    ax = sns.pairplot(df_diag_samples, vars=df_diag_samples.columns[:-1], hue = "locus_tag", corner = True)
    
    ax.labels = labels
    s1 = df_raw_tpm.T + 0.01
    s2 = df_raw_tpm.T + 0.01
    
    ax.map_offdiag(plot_diagonal)
    
    
    plt.suptitle(title, fontsize = 16)
    
    plt.savefig(filename, bbox_inches='tight')
    plt.show()
    print("\n")

# %%
def cloud_analysis_scatter(s1_name, s2_name, condition, filename):

    plt.figure(figsize=(13, 12))


    s1 = df_raw_tpm.T[s1_name] + 0.01
    s2 = df_raw_tpm.T[s2_name] + 0.01

    max_length = 20
    ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, alpha = 0.1, color = "gray")
    line = plt.plot([0, max_length],[0, max_length], color = "black", lw = 2.5, linestyle = ":", label = "Diagonal (for comparison)")


    s1 = df_all_samples_diag_genes[s1_name]
    s2 = df_all_samples_diag_genes[s2_name]

    labels = list(df_all_samples_diag_genes.T.columns)

    ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, hue = gene_to_diagnostic)
    # line = plt.plot([0, max_length],[0, max_length], color = "black", lw = 2.5, linestyle = ":", label = "Diagonal (for comparison)")

    plt.xlabel(s1_name, fontsize = 20)
    plt.ylabel(s2_name, fontsize = 20)

    # plt.xlim = (0, 1000)
    # plt.ylim = (0, 1000)
    ax.set(ylim=(0, max_length))
    ax.set(xlim=(0, max_length))
    
    sns.set(font_scale=1.4)


    plt.title("Diagnostic Gene Expression for " + condition + "\n samples: "  + s1_name +" and " + s2_name + "\n", fontsize = 20)
    plt.savefig(filename, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## PairwiseScatter  --> Seaborn Scatterplot

# %%
"""
Given two samples, plots a scatter plot of the genes'
expressions against each other in a pairwise manner

s1_name: sample 1 name
s2_name: sample 2 name
max_length: max distance occupied by plot axis
"""
def single_pairwise_scatter(s1_name, s2_name, max_length):
    plt.figure(figsize=(13, 12))

    s1 = df_all_samples_diag_genes[s1_name]
    s2 = df_all_samples_diag_genes[s2_name]

    scatter = sns.scatterplot(x = s1, y = s2, s = 50, hue = gene_to_diagnostic)
    line = plt.plot([0, max_length],[0, max_length], color = "black", lw = 2.5, linestyle = ":", label = "Diagonal (for comparison)")

    plt.xlabel(s1_name, fontsize = 12)
    plt.ylabel(s2_name, fontsize = 12)

    plt.title("Pairwise Plot of Diagnostic Gene Expression for "  + s1_name +" and " + s2_name, fontsize = 13)

    plt.show()

# %% [markdown]
# ***
# ## Diagnostic genes of interest

# %%
df_diagnostics
# Out:
#             Gene                           Function  \
# 0  EQU24_RS14140                bacteriohemerythrin
# 1  EQU24_RS17070  nifD; nitrogenase structural gene
# 2  MBURv2_160514                     heme synthesis
# 3  EQU24_RS01660            Mo transport (putative)
# 4  EQU24_RS07680                 CorA copper uptake
# 5  EQU24_RS01475            Mo-Formate DH subunit B
#
#                       Diagnostic for
# 0                      O2-limitation
# 1  N-limitation when also O2-limited
# 2                      Fe-limitation
# 3                      Mo-limitation
# 4                      Cu-limitation
# 5                       W-limitation

# %%
print("Genes not present in tpm data: ")
new_genes = []
for gene in df_diagnostics['Gene']:
    if gene not in df_raw_tpm.columns:
        new_genes.append(gene)
        print(gene)
# Out:
# Genes not present in tpm data:
# MBURv2_160514

# %%
df_clean_diagnostics = df_diagnostics[~df_diagnostics['Gene'].isin(new_genes)]
df_clean_diagnostics.index = np.arange(0,5)
df_clean_diagnostics
# Out:
#             Gene                           Function  \
# 0  EQU24_RS14140                bacteriohemerythrin
# 1  EQU24_RS17070  nifD; nitrogenase structural gene
# 2  EQU24_RS01660            Mo transport (putative)
# 3  EQU24_RS07680                 CorA copper uptake
# 4  EQU24_RS01475            Mo-Formate DH subunit B
#
#                       Diagnostic for
# 0                      O2-limitation
# 1  N-limitation when also O2-limited
# 2                      Mo-limitation
# 3                      Cu-limitation
# 4                       W-limitation

# %% [markdown]
# ### Note From Erin:
# - the alternate gene ID for the MBURv2_160514 gene is EQU24_RS20550 for our context
# - why do we have these differences in naming and what do they mean?

# %%
df_all_clean_diag = cp.deepcopy(df_diagnostics)
df_all_clean_diag['Gene'] = df_all_clean_diag['Gene'].apply(lambda x: "EQU24_RS20550" if x == "MBURv2_160514" else x)
df_all_clean_diag
# Out:
#             Gene                           Function  \
# 0  EQU24_RS14140                bacteriohemerythrin
# 1  EQU24_RS17070  nifD; nitrogenase structural gene
# 2  EQU24_RS20550                     heme synthesis
# 3  EQU24_RS01660            Mo transport (putative)
# 4  EQU24_RS07680                 CorA copper uptake
# 5  EQU24_RS01475            Mo-Formate DH subunit B
#
#                       Diagnostic for
# 0                      O2-limitation
# 1  N-limitation when also O2-limited
# 2                      Fe-limitation
# 3                      Mo-limitation
# 4                      Cu-limitation
# 5                       W-limitation

# %%
gene_to_diagnostic = {}

for row_num, gene in enumerate(df_all_clean_diag['Gene']):
    gene = df_all_clean_diag.loc[row_num, "Gene"]
    diagnostic = df_all_clean_diag.loc[row_num, "Diagnostic for"]
    
    gene_to_diagnostic[gene] = diagnostic

gene_to_diagnostic
# Out:
# {'EQU24_RS14140': 'O2-limitation',
#  'EQU24_RS17070': 'N-limitation when also O2-limited',
#  'EQU24_RS20550': 'Fe-limitation',
#  'EQU24_RS01660': 'Mo-limitation',
#  'EQU24_RS07680': 'Cu-limitation',
#  'EQU24_RS01475': 'W-limitation'}

# %% [markdown]
# ***
#
# ## Pair-wise Scatterplots of Diagnostic Gene Expression Between Samples of Same Condition

# %%
df_all_samples_diag_genes = df_raw_tpm[df_all_clean_diag['Gene']]

df_all_samples_diag_genes = df_all_samples_diag_genes.T
df_all_samples_diag_genes
# Out:
#                5GB1_ferm_Ack_QC_tpm  5GB1_ferm_WT_QC_tpm  \
# locus_tag
# EQU24_RS14140             28.603246            91.736391
# EQU24_RS17070              4.516511             4.915427
# EQU24_RS20550              0.737166             1.550983
# EQU24_RS01660              0.880606             0.808484
# EQU24_RS07680             11.813370            18.035879
# EQU24_RS01475            156.100482           166.467163
#
#                5GB1_FM03_TR1_QC_tpm  5GB1_FM03_TR2_QC_tpm  \
# locus_tag
# EQU24_RS14140            126.615893            133.906122
# EQU24_RS17070              1.415161              4.706019
# EQU24_RS20550              7.189146              8.782166
# EQU24_RS01660             10.409731             12.292511
# EQU24_RS07680            705.284978            695.267919
# EQU24_RS01475            710.925836            679.184146
#
#                5GB1_FM11_TR1_QC_tpm  5GB1_FM11_TR2_QC_tpm  5GB1_FM12_TR1_tpm  \
# locus_tag
# EQU24_RS14140            190.223530            227.676228          12.195826
# EQU24_RS17070              5.733278              6.482568           3.777780
# EQU24_RS20550            377.661666            520.364691           7.690962
# EQU24_RS01660              8.715799             13.301575          13.011242
# EQU24_RS07680            981.369041           1096.568169         311.417699
# EQU24_RS01475            691.719622            870.471342         718.889408
#
#                5GB1_FM12_TR1_QC_tpm  5GB1_FM12_TR2_tpm  5GB1_FM12_TR2_QC_tpm  \
# locus_tag
# EQU24_RS14140             11.991596          12.707627             10.781432
# EQU24_RS17070              3.216665           3.962612              3.874251
# EQU24_RS20550              7.945224           7.798588              6.930123
# EQU24_RS01660             12.239857          13.163323             12.523269
# EQU24_RS07680            308.519000         320.985003            318.935528
# EQU24_RS01475            712.968817         736.415121            731.392990
#
#                ...  5GB1_pA9_red_tpm  5GB1_pA9_yellow_tpm  \
# locus_tag      ...
# EQU24_RS14140  ...         38.911948            44.422399
# EQU24_RS17070  ...          9.092900             7.452042
# EQU24_RS20550  ...         15.845305            18.272994
# EQU24_RS01660  ...         30.170638            22.602789
# EQU24_RS07680  ...       1154.910241          1260.065707
# EQU24_RS01475  ...        564.000364           521.508289
#
#                5GB1C-5G-La-BR1_tpm  5GB1C-5G-La-BR2_tpm  5GB1C-5G-N-BR1_tpm  \
# locus_tag
# EQU24_RS14140          1656.111935          1323.221454         1716.583597
# EQU24_RS17070            23.727795            32.180850           22.646416
# EQU24_RS20550            22.523784            19.569386           22.989903
# EQU24_RS01660           115.948007           160.704714          118.818740
# EQU24_RS07680           211.770928           278.320377          262.069293
# EQU24_RS01475           627.650964           747.442530          863.022672
#
#                5GB1C-5G-N-BR2_tpm  5GB1C-JG15-La-BR1_tpm  \
# locus_tag
# EQU24_RS14140          831.997500            2179.236637
# EQU24_RS17070           51.485082              33.219206
# EQU24_RS20550           18.455492              25.761710
# EQU24_RS01660          119.488719             144.219179
# EQU24_RS07680          337.307671             205.812733
# EQU24_RS01475          553.101306             465.629865
#
#                5GB1C-JG15-La-BR2_tpm  5GB1C-JG15-N-BR1_tpm  \
# locus_tag
# EQU24_RS14140            2009.804320           2444.914424
# EQU24_RS17070              30.819280             28.186233
# EQU24_RS20550              26.330451             21.471359
# EQU24_RS01660             108.509206             93.315421
# EQU24_RS07680             216.719319            239.090549
# EQU24_RS01475             573.838592            588.255962
#
#                5GB1C-JG15-N-BR2_tpm
# locus_tag
# EQU24_RS14140           1353.895412
# EQU24_RS17070             21.973230
# EQU24_RS20550             17.228618
# EQU24_RS01660             82.055940
# EQU24_RS07680            323.579876
# EQU24_RS01475            795.488439
#
# [6 rows x 98 columns]

# %%
df_trial = df_all_samples_diag_genes[condition_to_sample.get("LanzaTech")]
df_trial['locus_tag'] = list(df_all_samples_diag_genes.index)
df_trial
# Out:
# <ipython-input-19-b581030c4245>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trial['locus_tag'] = list(df_all_samples_diag_genes.index)
#                5GB1_LTrecycle_TR1_tpm  5GB1_LTrecycle_TR1_QC_tpm  \
# locus_tag
# EQU24_RS14140               26.753613                  26.984415
# EQU24_RS17070                6.163326                   8.645851
# EQU24_RS20550               17.013339                  17.704878
# EQU24_RS01660               26.146173                  31.133299
# EQU24_RS07680              847.720835                 846.670649
# EQU24_RS01475              530.667093                 528.699226
#
#                    locus_tag
# locus_tag
# EQU24_RS14140  EQU24_RS14140
# EQU24_RS17070  EQU24_RS17070
# EQU24_RS20550  EQU24_RS20550
# EQU24_RS01660  EQU24_RS01660
# EQU24_RS07680  EQU24_RS07680
# EQU24_RS01475  EQU24_RS01475

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    for condition in list_conditions: 
        df_cur_condition = np.log(df_all_samples_diag_genes[condition_to_sample.get(condition)])
        df_cur_condition['locus_tag'] = list(df_all_samples_diag_genes.index)
        #df_cur_condition['diagnostic'] = df_cur_condition['locus_tag'].apply(lambda x: gene_to_diagnostic.get(x))

        #           Diagnostic Pairwise + Condition
        filename = "plots/pairwise_expression/diag_pw_" + str(condition)
        title = "Diagnostic Gene Expression for Samples of Condition " + str(condition)
        
        sample_pairwise_scatter(df_cur_condition, title, filename)

# %% [markdown]
# ## uMax unflagged samples that correlated poorly with other samples
# - 5GB1_FM20_TR3_tpm
# - 5GB1_FM21_TR2_tpm

# %%
# Highly correlated unflagged samples (that poorly correlated with others)
s1_name =  "5GB1_FM20_TR3_tpm"
s2_name = "5GB1_FM21_TR2_tpm"
max_length = 1000

single_pairwise_scatter(s1_name, s2_name, max_length)

# %%
# Relatively less correlated unflagged samples
s1_name =  "5GB1_FM20_TR3_tpm" # Unflagged Exception
s2_name = "5GB1_FM20_TR3_UW_tpm"  # Correlated with majority
max_length = 1000

single_pairwise_scatter(s1_name, s2_name, max_length)

# %% [markdown]
# ## Gene Cloud Plot

# %%
def plot_cloud(s1_name, s2_name, **kws):
    s1 = df_raw_tpm.T[s1_name] + 0.01
    s2 = df_raw_tpm.T[s2_name] + 0.01

    ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, alpha = 0.02)

# %%
df_raw_tpm.T
# Out:
#                5GB1_ferm_Ack_QC_tpm  5GB1_ferm_WT_QC_tpm  \
# locus_tag
# EQU24_RS00005              2.933003             6.033848
# EQU24_RS00010              1.607784             3.895284
# EQU24_RS00015              1.415515             2.549771
# EQU24_RS00020              3.200081             4.301580
# EQU24_RS00025              1.522728             3.797084
# ...                             ...                  ...
# EQU24_RS22135              2.300157             3.217944
# EQU24_RS22140              5.261582            12.526353
# EQU24_RS22145              9.389775            21.072962
# EQU24_RS22150             21.657488            42.254357
# EQU24_RS22155             27.832080            41.530602
#
#                5GB1_FM03_TR1_QC_tpm  5GB1_FM03_TR2_QC_tpm  \
# locus_tag
# EQU24_RS00005             48.864921             52.197450
# EQU24_RS00010             51.315629             54.947425
# EQU24_RS00015             33.906257             29.979783
# EQU24_RS00020             64.584281             72.717824
# EQU24_RS00025             74.801354             62.709260
# ...                             ...                   ...
# EQU24_RS22135            104.488835            103.864151
# EQU24_RS22140            379.686212            401.742811
# EQU24_RS22145            500.129230            495.262554
# EQU24_RS22150           1191.565348           1232.784967
# EQU24_RS22155            796.964423            724.291958
#
#                5GB1_FM11_TR1_QC_tpm  5GB1_FM11_TR2_QC_tpm  5GB1_FM12_TR1_tpm  \
# locus_tag
# EQU24_RS00005             25.751902             34.928170          28.322788
# EQU24_RS00010             37.216017             40.094206          27.387700
# EQU24_RS00015             21.716802             27.871558          16.570863
# EQU24_RS00020             53.032824             55.595529          36.795081
# EQU24_RS00025             46.348014             57.992363          27.432559
# ...                             ...                   ...                ...
# EQU24_RS22135             78.264069             59.685923          58.833576
# EQU24_RS22140            208.094267            210.820167         204.760175
# EQU24_RS22145            260.011454            331.355028         300.766500
# EQU24_RS22150            666.589153            860.248081         828.322141
# EQU24_RS22155            461.697526            503.720248         544.969944
#
#                5GB1_FM12_TR1_QC_tpm  5GB1_FM12_TR2_tpm  5GB1_FM12_TR2_QC_tpm  \
# locus_tag
# EQU24_RS00005             28.461759          28.479425             29.472757
# EQU24_RS00010             28.648564          26.498988             26.821965
# EQU24_RS00015             15.562811          16.589291             16.958650
# EQU24_RS00020             36.401903          37.513079             35.833478
# EQU24_RS00025             30.380176          26.852591             26.467246
# ...                             ...                ...                   ...
# EQU24_RS22135             57.223346          66.382013             69.196352
# EQU24_RS22140            204.759505         211.282600            218.557992
# EQU24_RS22145            309.148602         312.637538            317.603906
# EQU24_RS22150            819.209523         810.533604            835.528579
# EQU24_RS22155            532.969046         487.035415            514.838828
#
#                ...  5GB1_pA9_red_tpm  5GB1_pA9_yellow_tpm  \
# locus_tag      ...
# EQU24_RS00005  ...         38.557373            38.810668
# EQU24_RS00010  ...         52.552767            52.461746
# EQU24_RS00015  ...         31.350991            34.914128
# EQU24_RS00020  ...         74.848501            80.850761
# EQU24_RS00025  ...         50.324948            49.349547
# ...            ...               ...                  ...
# EQU24_RS22135  ...         70.918047            92.044879
# EQU24_RS22140  ...        328.789579           403.009110
# EQU24_RS22145  ...        301.203428           329.903989
# EQU24_RS22150  ...        550.448048           679.393946
# EQU24_RS22155  ...        629.866044           723.410948
#
#                5GB1C-5G-La-BR1_tpm  5GB1C-5G-La-BR2_tpm  5GB1C-5G-N-BR1_tpm  \
# locus_tag
# EQU24_RS00005            37.444214            40.246006           40.100118
# EQU24_RS00010            42.676553            49.210083           46.798476
# EQU24_RS00015            21.479309            24.204682           22.171104
# EQU24_RS00020            54.959319            64.911376           59.653059
# EQU24_RS00025            34.539657            36.521074           37.789611
# ...                            ...                  ...                 ...
# EQU24_RS22135            20.691249            26.000334           20.753333
# EQU24_RS22140           105.587429           138.423469          100.648922
# EQU24_RS22145            69.198876            75.440610           62.460976
# EQU24_RS22150           202.139374           195.134615          214.993010
# EQU24_RS22155           327.672277           373.444049          368.678698
#
#                5GB1C-5G-N-BR2_tpm  5GB1C-JG15-La-BR1_tpm  \
# locus_tag
# EQU24_RS00005           33.432274              39.880174
# EQU24_RS00010           48.142385              45.465136
# EQU24_RS00015           22.006566              22.658157
# EQU24_RS00020           64.648318              69.119079
# EQU24_RS00025           39.358066              38.992158
# ...                           ...                    ...
# EQU24_RS22135           30.766617              22.101468
# EQU24_RS22140          166.101675              96.169044
# EQU24_RS22145           59.523445              47.641158
# EQU24_RS22150          259.828426             134.795621
# EQU24_RS22155          404.714461             265.487592
#
#                5GB1C-JG15-La-BR2_tpm  5GB1C-JG15-N-BR1_tpm  \
# locus_tag
# EQU24_RS00005              38.355431             30.247582
# EQU24_RS00010              46.498139             37.152951
# EQU24_RS00015              22.753325             19.407103
# EQU24_RS00020              65.643179             57.590223
# EQU24_RS00025              35.870964             41.462392
# ...                              ...                   ...
# EQU24_RS22135              19.753259             20.027390
# EQU24_RS22140              93.527806             89.780995
# EQU24_RS22145              60.667488             55.739018
# EQU24_RS22150             160.260255            174.197473
# EQU24_RS22155             308.428817            286.670085
#
#                5GB1C-JG15-N-BR2_tpm
# locus_tag
# EQU24_RS00005             41.248441
# EQU24_RS00010             52.902410
# EQU24_RS00015             29.834124
# EQU24_RS00020             68.306759
# EQU24_RS00025             40.227192
# ...                             ...
# EQU24_RS22135             24.508375
# EQU24_RS22140            130.851229
# EQU24_RS22145             66.415222
# EQU24_RS22150            164.123473
# EQU24_RS22155            301.751157
#
# [4213 rows x 98 columns]

# %%
# Intention: Plot the diagnostic genes along side the respective gene clouds. 
# Error: resulting plot is too large supposedly ==> will investigate!

import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    df_raw_tpm_psuedocount = df_raw_tpm.T + 0.01
    df_diag_condition = df_all_samples_diag_genes + 0.01
    
    condition = "LanzaTech"
    #for condition in list_conditions: 
    df_diag_condition = np.log(df_all_samples_diag_genes[condition_to_sample.get(condition)])
    df_diag_condition['locus_tag'] = list(df_all_samples_diag_genes.index)
    
    df_cur_condition = np.log(df_raw_tpm_psuedocount[condition_to_sample.get(condition)])
    df_cur_condition["locus_tag"] = df_cur_condition.index

    #           Diagnostic Pairwise + Condition
    filename = "plots/pairwise_expression/gene_cloud_pw_" + str(condition)
    title = "Diagnostic Gene Expression for Samples of Condition " + str(condition)

    sample_pairwise_scatter(df_diag_condition, df_cur_condition, title, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-1aaa41ea3b6c> in <module>
#      21     title = "Diagnostic Gene Expression for Samples of Condition " + str(condition)
#      22
# ---> 23     sample_pairwise_scatter(df_diag_condition, df_cur_condition, title, filename)
#
# TypeError: sample_pairwise_scatter() takes 3 positional arguments but 4 were given

# %%
df_raw_tpm_psuedocount = df_raw_tpm.T + 0.01
for condition in list_conditions: 
    df_cur_condition = np.log(df_raw_tpm_psuedocount[condition_to_sample.get(condition)])

df_cur_condition
# Out:
#                5GB1_vial_woLa_TR2_tpm  5GB1C-5G-N-BR1_tpm  5GB1C-5G-N-BR2_tpm  \
# locus_tag
# EQU24_RS00005                3.097914            3.691629            3.509821
# EQU24_RS00010                3.508944            3.846064            3.874371
# EQU24_RS00015                3.109261            3.099241            3.091795
# EQU24_RS00020                3.590353            4.088713            4.169117
# EQU24_RS00025                3.969501            3.632299            3.672955
# ...                               ...                 ...                 ...
# EQU24_RS22135                2.605691            3.033189            3.426755
# EQU24_RS22140                4.118937            4.611738            5.112660
# EQU24_RS22145                4.524068            4.134702            4.086538
# EQU24_RS22150                5.500006            5.370652            5.560060
# EQU24_RS22155                5.644967            5.909953            6.003206
#
#                5GB1C-JG15-N-BR1_tpm  5GB1C-JG15-N-BR2_tpm
# locus_tag
# EQU24_RS00005              3.409747              3.719856
# EQU24_RS00010              3.615312              3.968638
# EQU24_RS00015              2.966154              3.395988
# EQU24_RS00020              4.053526              4.224155
# EQU24_RS00025              3.725028              3.694792
# ...                             ...                   ...
# EQU24_RS22135              2.997600              3.199423
# EQU24_RS22140              4.497485              4.874137
# EQU24_RS22145              4.020860              4.196077
# EQU24_RS22150              5.160247              5.100680
# EQU24_RS22155              5.658367              5.709636
#
# [4213 rows x 5 columns]

# %%
s1_name =  "5GB1_FM20_TR3_tpm" # Unflagged Exception
s2_name = "5GB1_FM20_TR3_UW_tpm"  # Correlated with major

plt.figure(figsize=(13, 12))


s1 = df_raw_tpm.T[s1_name] + 0.01
s2 = df_raw_tpm.T[s2_name] + 0.01

max_length = 20
ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, alpha = 0.02)
line = plt.plot([0, max_length],[0, max_length], color = "black", lw = 2.5, linestyle = ":", label = "Diagonal (for comparison)")


s1 = df_all_samples_diag_genes[s1_name]
s2 = df_all_samples_diag_genes[s2_name]

ax = sns.scatterplot(x = np.log(s1), y = np.log(s2), s = 50, hue = gene_to_diagnostic)
# line = plt.plot([0, max_length],[0, max_length], color = "black", lw = 2.5, linestyle = ":", label = "Diagonal (for comparison)")

plt.xlabel(s1_name, fontsize = 12)
plt.ylabel(s2_name, fontsize = 12)

# plt.xlim = (0, 1000)
# plt.ylim = (0, 1000)
ax.set(ylim=(0, max_length))
ax.set(xlim=(0, max_length))

plt.title("Pairwise Plot of Diagnostic Gene Expression for "  + s1_name +" and " + s2_name, fontsize = 13)

plt.show()

# %% [markdown]
# ## Individual Samples of Interest Visualized

# %%
df_unstable_diag_samples
# Out:
#                 Condition               Sample 1                Sample 2  \
# 0                    MeOH   5GB1_FM18_TR1_QC_tpm    5GB1_FM23_TR3_QC_tpm
# 1   NO3_lowO2_slow_growth   5GB1_FM80_t2_TR1_tpm    5GB1_FM81_t2_TR3_tpm
# 2   NO3_lowO2_slow_growth   5GB1_FM80_t2_TR1_tpm    5GB1_FM80_t4_TR1_tpm
# 3   NO3_lowO2_slow_growth   5GB1_FM80_t4_TR1_tpm    5GB1_FM81_t2_TR3_tpm
# 4             NoLanthanum   5GB1C-JG15-N-BR2_tpm  5GB1_vial_woLa_TR2_tpm
# 5           WithLanthanum  5GB1C-JG15-La-BR2_tpm   5GB1_vial_wLa_TR3_tpm
# 6       lowO2_fast_growth   5GB1_FM11_TR2_QC_tpm       5GB1_FM19_TR3_tpm
# 7       lowO2_fast_growth   5GB1_FM11_TR2_QC_tpm    5GB1_FM22_TR3_UW_tpm
# 8       lowO2_slow_growth   5GB1_ferm_Ack_QC_tpm    5GB1_FM69_t2_TR1_tpm
# 9                    uMax   5GB1_FM03_TR1_QC_tpm    5GB1_FM21_TR2_UW_tpm
# 10      lowO2_fast_growth      5GB1_FM19_TR3_tpm    5GB1_FM22_TR3_UW_tpm
#
#          Summary_Name
# 0   FM18_TR1_FM23_TR3
# 1   FM80_TR1_FM81_TR3
# 2     FM80_t2_FM80_t4
# 3     FM80_t4_FM81_t2
# 4       JG15_woLa_TR2
# 5        wLa_TR3_JG15
# 6   FM11_TR2_FM19_TR3
# 7   FM22_TR3_FM11_TR2
# 8   ferm_Ack_FM69_TR1
# 9   FM03_TR1_FM21_TR2
# 10  FM19_TR3_FM22_TR3

# %%
for i in range(0,len(df_unstable_diag_samples["Condition"])):
    plot_data = df_unstable_diag_samples.iloc[i]
    condition = plot_data["Condition"]
    s1 = str(plot_data["Sample 1"])
    s2 = str(plot_data["Sample 2"])
    filename = "plots/gene_cloud_pairwise_expression/ca_" + str(plot_data["Summary_Name"])
    
    cloud_analysis_scatter(s1, s2, condition, filename)

# %%
df_raw_tpm.T[s1_name]
# Out:
# locus_tag
# EQU24_RS00005      52.395498
# EQU24_RS00010      65.012759
# EQU24_RS00015      33.970709
# EQU24_RS00020      73.457941
# EQU24_RS00025      38.467325
#                     ...
# EQU24_RS22135      87.991196
# EQU24_RS22140     432.863917
# EQU24_RS22145     435.681411
# EQU24_RS22150    1159.122423
# EQU24_RS22155    1197.548565
# Name: 5GB1_FM20_TR3_tpm, Length: 4213, dtype: float64

# %% [markdown]
# ## Check Diagnostic Conditions

# %%
gene_to_diagnostic
# Out:
# {'EQU24_RS14140': 'O2-limitation',
#  'EQU24_RS17070': 'N-limitation when also O2-limited',
#  'EQU24_RS20550': 'Fe-limitation',
#  'EQU24_RS01660': 'Mo-limitation',
#  'EQU24_RS07680': 'Cu-limitation',
#  'EQU24_RS01475': 'W-limitation'}
