# %%
import altair as alt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

from collections import defaultdict
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
import json

# %%
# load cluster data
copper_genes_file = 'data/regulatory_response_genes.csv'

# load TPM data
df_copper_genes = pd.read_csv(copper_genes_file).fillna('')
df_copper_genes.columns = df_copper_genes.iloc[0]
df_copper_genes.drop(axis = 0, index = 0)
# Out:
# 0         mage_locus mage_gene     ncbi_locus ncbi_gene  \
# 1      MBURv2_210004            EQU24_RS19505
# 2      MBURv2_210005            EQU24_RS19500
# 3      MBURv2_210008            EQU24_RS19485
# 4      MBURv2_210010            EQU24_RS19475
# 5      MBURv2_210011            EQU24_RS19470
# 6      MBURv2_210012            EQU24_RS19465
# 7      MBURv2_210013            EQU24_RS19460
# 8      MBURv2_210014            EQU24_RS19455
# 9      MBURv2_210015            EQU24_RS19450
# 10     MBURv2_210016            EQU24_RS19445
# 11     MBURv2_200002            EQU24_RS19520
# 12     MBURv2_210006            EQU24_RS19495
# 13     MBURv2_250053            EQU24_RS15800
# 14     MBURv2_130844            EQU24_RS01900
# 15     MBURv2_160425            EQU24_RS21005
# 16     MBURv2_130758            EQU24_RS02325
# 17     MBURv2_160072            EQU24_RS00675
# 18     MBURv2_130715            EQU24_RS02555
# 19     MBURv2_130858                not found
# 20     MBURv2_130857            EQU24_RS01840
# 21     MBURv2_130859      mscL  EQU24_RS01835      mscL
# 22     MBURv2_210075            EQU24_RS19170
# 23     MBURv2_130051      mmoX  EQU24_RS05885
# 24     MBURv2_200002            EQU24_RS19520
# 25     MBURv2_160426            EQU24_RS21000
# 26     MBURv2_160425            EQU24_RS21005
# 27     MBURv2_160073            EQU24_RS00670
# 28     MBURv2_130055            EQU24_RS05870
# 29      MBURv2_50246            EQU24_RS10665
# 30     MBURv2_130056                not found
# 31     MBURv2_130055            EQU24_RS05870
# 32     MBURv2_130057      glnS  EQU24_RS05865
# 33     MBURv2_250053            EQU24_RS15800
# 34     MBURv2_210002            EQU24_RS19515
# 35     MBURv2_210001            EQU24_RS04725
# 36     MBURv2_210003            EQU24_RS19510
# 37     MBURv2_190133            EQU24_RS16960
# 38     MBURv2_130048      mmoZ  EQU24_RS05900
# 39     MBURv2_130052                not found
# 40     MBURv2_130053            EQU24_RS05880
# 41     MBURv2_130049      mmoB  EQU24_RS05895
# 42     MBURv2_130050      mmoY  EQU24_RS05890
# 43     MBURv2_130046      mmoC  EQU24_RS05910
# 44     MBURv2_130047            EQU24_RS05905      mmoD
# 45     MBURv2_130045            EQU24_RS05915
# 46     MBURv2_130044            EQU24_RS05920
# 47     MBURv2_130043      groL  EQU24_RS05925
# 48     MBURv2_210045      pmoC  EQU24_RS19315
# 49     MBURv2_210046      pmoA  EQU24_RS19310
# 50     MBURv2_210047      pmoB  EQU24_RS19305
# 51     MBURv2_210009            EQU24_RS19480
# 52     MBURv2_210007            EQU24_RS19490
# 53      MBURv2_50249            EQU24_RS10650
#
# 0                                        ncbi_product   regulation  \
# 1                                hypothetical protein  repressible
# 2                                hypothetical protein  repressible
# 3                                hypothetical protein  repressible
# 4                                hypothetical protein  repressible
# 5                          S8 family serine peptidase  repressible
# 6                    type II secretion system protein  repressible
# 7                                hypothetical protein  repressible
# 8                                  MoxR family ATPase  repressible
# 9                     DUF58 domain-containing protein  repressible
# 10                  DUF3488 domain-containing protein  repressible
# 11                   type II secretion system protein  repressible
# 12                               hypothetical protein  repressible
# 13                            TonB-dependent receptor  repressible
# 14                        RNA polymerase sigma factor  repressible
# 15                               hypothetical protein  repressible
# 16                               hypothetical protein  repressible
# 17                                  c-type cytochrome  repressible
# 18                               hypothetical protein    inducible
# 19
# 20                               5'-deoxynucleotidase      unclear
# 21  large-conductance mechanosensitive channel pro...      unclear
# 22                                              porin    inducible
# 23                              methane monooxygenase  repressible
# 24                   type II secretion system protein  repressible
# 25                               hypothetical protein  repressible
# 26                               hypothetical protein  repressible
# 27                               hypothetical protein  repressible
# 28                               hypothetical protein  repressible
# 29                                 chemotaxis protein  repressible
# 30
# 31                               hypothetical protein  repressible
# 32  glutamine--tRNA ligase/YqeY domain fusion protein      unclear
# 33                            TonB-dependent receptor  repressible
# 34                               hypothetical protein  repressible
# 35                               Hsp70 family protein      unclear
# 36                  DUF2939 domain-containing protein  repressible
# 37                            TonB-dependent receptor      unclear
# 38                               hypothetical protein  repressible
# 39
# 40                               hypothetical protein  repressible
# 41                              methane monooxygenase  repressible
# 42                              methane monooxygenase  repressible
# 43  2Fe-2S iron-sulfur cluster binding domain-cont...  repressible
# 44  soluble methane monooxygenase-binding protein ...  repressible
# 45                     BLUF domain-containing protein  repressible
# 46                               hypothetical protein  repressible
# 47                                   chaperonin GroEL  repressible
# 48  methane monooxygenase/ammonia monooxygenase su...    inducible
# 49  methane monooxygenase/ammonia monooxygenase su...    inducible
# 50  methane monooxygenase/ammonia monooxygenase su...    inducible
# 51                             DUF3438 family protein  repressible
# 52          type II secretion system F family protein  repressible
# 53              HEAT repeat domain-containing protein  repressible
#
# 0                                               notes
# 1         Cluster 8 and 18 genes from Alexey's thesis
# 2         Cluster 8 and 18 genes from Alexey's thesis
# 3         Cluster 8 and 18 genes from Alexey's thesis
# 4         Cluster 8 and 18 genes from Alexey's thesis
# 5         Cluster 8 and 18 genes from Alexey's thesis
# 6         Cluster 8 and 18 genes from Alexey's thesis
# 7         Cluster 8 and 18 genes from Alexey's thesis
# 8         Cluster 8 and 18 genes from Alexey's thesis
# 9         Cluster 8 and 18 genes from Alexey's thesis
# 10        Cluster 8 and 18 genes from Alexey's thesis
# 11         Doc "from Cassie" from Joseph, repressible
# 12         Doc "from Cassie" from Joseph, repressible
# 13         Doc "from Cassie" from Joseph, repressible
# 14         Doc "from Cassie" from Joseph, repressible
# 15         Doc "from Cassie" from Joseph, repressible
# 16         Doc "from Cassie" from Joseph, repressible
# 17         Doc "from Cassie" from Joseph, repressible
# 18           Doc "from Cassie" from Joseph, inducible
# 19           Doc "from Cassie" from Joseph, inducible
# 20  Near gene MBURv2_130858 in doc "from Cassie" f...
# 21  Near gene MBURv2_130858 in doc "from Cassie" f...
# 22           Doc "from Cassie" from Joseph, inducible
# 23             Cu Expression analysis doc from Joseph
# 24             Cu Expression analysis doc from Joseph
# 25             Cu Expression analysis doc from Joseph
# 26             Cu Expression analysis doc from Joseph
# 27             Cu Expression analysis doc from Joseph
# 28             Cu Expression analysis doc from Joseph
# 29             Cu Expression analysis doc from Joseph
# 30             Cu Expression analysis doc from Joseph
# 31  Near gene MBURv2_130056 in Cu Expression analy...
# 32  Near gene MBURv2_130056 in Cu Expression analy...
# 33             Cu Expression analysis doc from Joseph
# 34             Cu Expression analysis doc from Joseph
# 35             Cu Expression analysis doc from Joseph
# 36             Cu Expression analysis doc from Joseph
# 37             Cu Expression analysis doc from Joseph
# 38             Cu Expression analysis doc from Joseph
# 39             Cu Expression analysis doc from Joseph
# 40  Near gene MBURv2_130052 in Cu Expression analy...
# 41             Cu Expression analysis doc from Joseph
# 42             Cu Expression analysis doc from Joseph
# 43             Cu Expression analysis doc from Joseph
# 44             Cu Expression analysis doc from Joseph
# 45             Cu Expression analysis doc from Joseph
# 46             Cu Expression analysis doc from Joseph
# 47             Cu Expression analysis doc from Joseph
# 48                             known copper induction
# 49                             known copper induction
# 50                             known copper induction
# 51  noticed expression repsonse to no/low/med copp...
# 52  noticed expression repsonse to no/low/med copp...
# 53  noticed expression repsonse to no/low/med copp...
